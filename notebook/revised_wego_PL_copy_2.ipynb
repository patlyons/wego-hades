# %%
import requests
import json
import pandas as pd
import numpy as np
from shapely.geometry import Point
import geopandas as gpd
import matplotlib.pyplot as plt
import folium
import re
from folium.plugins import MarkerCluster
from folium.plugins import FastMarkerCluster
import shapely.wkt

# %matplotlib inline

# %%
with open('../data/WeGo.json') as fi:
    credentials = json.load(fi)

# %%
Authorization = credentials['Authorization']

# %%
URL = 'https://api.goswift.ly/speed-map/nashville/route/23'


headers = {'Authorization': Authorization,
          'Content-Type': 'application/json'}

# %%
def concat_frames_columns_do(geo_response, response, date_range, time_range='9am-2:30pm', days='m-f', in_or_out='outbound'):
    """This function pulls in two API requests, puts one in a geodataframe the other in a dataframe and concats desired columns"""
    geo_df = gpd.GeoDataFrame.from_features(geo_response.json()['features'])
    res_df = pd.DataFrame(response.json()['data']['segments'])
    full_df = pd.concat([geo_df, res_df[['countForSegment', 'percent20Secs']]], axis = 1)
    full_df['dates'] = date_range
    full_df['time'] = time_range
    full_df['days_of_week'] = days
    full_df['direction']= in_or_out
    full_df['max_seg_count'] = full_df['countForSegment'].max()
    full_df['proportion_of_segments'] = full_df['countForSegment']/full_df['max_seg_count']
    return full_df

# %%
params = {
    'direction': '0',
    'startDate': '01-25-2022',
    'endDate' : '02-24-2022',
    'beginTime' : '09:00',
    'endTime' : '14:30',
    'daysOfWeek' : '1,2,3,4,5',
    'excludeDates': '02-18-2022',
    'format' : 'geojson',
    'resolution': 'hiRes',
}


params1 = {
    'direction': '0',
    'startDate': '01-25-2022',
    'endDate' : '02-24-2022',
    'beginTime' : '09:00',
    'endTime' : '14:30',
    'daysOfWeek' : '1,2,3,4,5',
    'excludeDates': '02-18-2022',
    'resolution': 'hiRes',
}

# %%
do_janfeb23 = concat_frames_columns_do(requests.get(URL, params = params, headers = headers), 
                              requests.get(URL, params = params1, headers = headers), '01/25/22 - 02/24/22')
do_janfeb23.head(1)
# Out:
#                                             geometry fromStopId  \
# 0  LINESTRING (-86.75929 36.24254, -86.75955 36.2...   DOVDICWF
#
#                        fromStopName toStopId             toStopName  \
# 0  Doverside Dr & Dickerson Pike Wb    DWMRT  Dickerson Rd Wal Mart
#
#    pathLengthMeters  averageTravelSeconds  averageTravelSpeed  maxSecs  \
# 0             24.51              2.296379           10.673325    8.607
#
#    percent90Secs  ...  percent10Secs  minSecs  countForSegment  percent20Secs  \
# 0          2.742  ...          1.851    0.644              594          1.959
#
#                  dates        time  days_of_week  direction max_seg_count  \
# 0  01/25/22 - 02/24/22  9am-2:30pm           m-f   outbound           609
#
#   proportion_of_segments
# 0               0.975369
#
# [1 rows x 24 columns]

# %%
params = {
    'direction': '0',
    'startDate': '02-25-2022',
    'endDate' : '03-26-2022',
    'beginTime' : '09:00',
    'endTime' : '14:30',
    'daysOfWeek' : '1,2,3,4,5',
    'excludeDates': '03-14-2022,03-15-2022,03-16-2022,03-17-2022,03-18-2022',
    'format' : 'geojson',
    'resolution': 'hiRes',
}


params1 = {
    'direction': '0',
    'startDate': '02-25-2022',
    'endDate' : '03-26-2022',
    'beginTime' : '09:00',
    'endTime' : '14:30',
    'daysOfWeek' : '1,2,3,4,5',
    'excludeDates': '03-14-2022,03-15-2022,03-16-2022,03-17-2022,03-18-2022',
    'resolution': 'hiRes',
}

# %%
do_febmarch23 = concat_frames_columns_do(requests.get(URL, params = params, headers = headers), 
                              requests.get(URL, params = params1, headers = headers), '02/25/22 - 03/26/22')
do_febmarch23.head(1)
# Out:
#                                             geometry fromStopId  \
# 0  LINESTRING (-86.75929 36.24254, -86.75955 36.2...   DOVDICWF
#
#                        fromStopName toStopId             toStopName  \
# 0  Doverside Dr & Dickerson Pike Wb    DWMRT  Dickerson Rd Wal Mart
#
#    pathLengthMeters  averageTravelSeconds  averageTravelSpeed  maxSecs  \
# 0             24.51              2.290051           10.702818   16.415
#
#    percent90Secs  ...  percent10Secs  minSecs  countForSegment  percent20Secs  \
# 0          2.688  ...          1.818    0.865              432           1.91
#
#                  dates        time  days_of_week  direction max_seg_count  \
# 0  02/25/22 - 03/26/22  9am-2:30pm           m-f   outbound           447
#
#   proportion_of_segments
# 0               0.966443
#
# [1 rows x 24 columns]

# %%
params = {
    'direction': '0',
    'startDate': '03-27-2022',
    'endDate' : '04-26-2022',
    'beginTime' : '09:00',
    'endTime' : '14:30',
    'daysOfWeek' : '1,2,3,4,5',
    'excludeDates': '04-14-2022,04-15-2022',
    'format' : 'geojson',
    'resolution': 'hiRes',
}


params1 = {
    'direction': '0',
    'startDate': '03-27-2022',
    'endDate' : '04-26-2022',
    'beginTime' : '09:00',
    'endTime' : '14:30',
    'daysOfWeek' : '1,2,3,4,5',
    'excludeDates': '04-14-2022,04-15-2022',
    'resolution': 'hiRes',
}

# %%
do_marchapr23 = concat_frames_columns_do(requests.get(URL, params = params, headers = headers), 
                              requests.get(URL, params = params1, headers = headers), '03/27/22 - 04/26/22')
do_marchapr23.head(1)
# Out:
#                                             geometry fromStopId  \
# 0  LINESTRING (-86.75929 36.24254, -86.75955 36.2...   DOVDICWF
#
#                        fromStopName toStopId             toStopName  \
# 0  Doverside Dr & Dickerson Pike Wb    DWMRT  Dickerson Rd Wal Mart
#
#    pathLengthMeters  averageTravelSeconds  averageTravelSpeed  maxSecs  \
# 0             24.51               2.32794           10.528622    9.319
#
#    percent90Secs  ...  percent10Secs  minSecs  countForSegment  percent20Secs  \
# 0          2.742  ...          1.884    1.249              551          2.007
#
#                  dates        time  days_of_week  direction max_seg_count  \
# 0  03/27/22 - 04/26/22  9am-2:30pm           m-f   outbound           556
#
#   proportion_of_segments
# 0               0.991007
#
# [1 rows x 24 columns]

# %%
params = {
    'direction': '0',
    'startDate': '04-27-2022',
    'endDate' : '05-26-2022',
    'beginTime' : '09:00',
    'endTime' : '14:30',
    'daysOfWeek' : '1,2,3,4,5',
    'format' : 'geojson',
    'resolution': 'hiRes',
}


params1 = {
    'direction': '0',
    'startDate': '04-27-2022',
    'endDate' : '05-26-2022',
    'beginTime' : '09:00',
    'endTime' : '14:30',
    'daysOfWeek' : '1,2,3,4,5',
    'resolution': 'hiRes',
}

# %%
do_aprmay23 = concat_frames_columns_do(requests.get(URL, params = params, headers = headers), 
                              requests.get(URL, params = params1, headers = headers), '04/27/22 - 05/26/22')
do_aprmay23.head(1)
# Out:
#                                             geometry fromStopId  \
# 0  LINESTRING (-86.75929 36.24254, -86.75955 36.2...   DOVDICWF
#
#                        fromStopName toStopId             toStopName  \
# 0  Doverside Dr & Dickerson Pike Wb    DWMRT  Dickerson Rd Wal Mart
#
#    pathLengthMeters  averageTravelSeconds  averageTravelSpeed  maxSecs  \
# 0             24.51              2.335774            10.49331    9.167
#
#    percent90Secs  ...  percent10Secs  minSecs  countForSegment  percent20Secs  \
# 0          2.884  ...           1.85    1.579              575          1.968
#
#                  dates        time  days_of_week  direction max_seg_count  \
# 0  04/27/22 - 05/26/22  9am-2:30pm           m-f   outbound           586
#
#   proportion_of_segments
# 0               0.981229
#
# [1 rows x 24 columns]

# %%
params = {
    'direction': '0',
    'startDate': '05-26-2022',
    'endDate' : '06-25-2022',
    'beginTime' : '09:00',
    'endTime' : '14:30',
    'daysOfWeek' : '1,2,3,4,5',
    'excludeDates' : '05-30-2022',
    'format' : 'geojson',
    'resolution': 'hiRes',
}


params1 = {
    'direction': '0',
    'startDate': '05-26-2022',
    'endDate' : '06-25-2022',
    'beginTime' : '09:00',
    'endTime' : '14:30',
    'daysOfWeek' : '1,2,3,4,5',
    'excludeDates' : '05-30-2022',
    'resolution': 'hiRes',
}

# %%
do_mayjune23 = concat_frames_columns_do(requests.get(URL, params = params, headers = headers), 
                              requests.get(URL, params = params1, headers = headers), '05/26/22 - 06/25/22')
do_mayjune23.head(1)
# Out:
#                                             geometry fromStopId  \
# 0  LINESTRING (-86.75929 36.24254, -86.75955 36.2...   DOVDICWF
#
#                        fromStopName toStopId             toStopName  \
# 0  Doverside Dr & Dickerson Pike Wb    DWMRT  Dickerson Rd Wal Mart
#
#    pathLengthMeters  averageTravelSeconds  averageTravelSpeed  maxSecs  \
# 0             24.51              2.306566           10.626186     5.98
#
#    percent90Secs  ...  percent10Secs  minSecs  countForSegment  percent20Secs  \
# 0          2.797  ...          1.829    1.589              567          1.955
#
#                  dates        time  days_of_week  direction max_seg_count  \
# 0  05/26/22 - 06/25/22  9am-2:30pm           m-f   outbound           571
#
#   proportion_of_segments
# 0               0.992995
#
# [1 rows x 24 columns]

# %%
params = {
    'direction': '0',
    'startDate': '06-26-2022',
    'endDate' : '07-26-2022',
    'beginTime' : '09:00',
    'endTime' : '14:30',
    'daysOfWeek' : '1,2,3,4,5',
    'excludeDates' : '07-04-2022',
    'format' : 'geojson',
    'resolution': 'hiRes',
}


params1 = {
    'direction': '0',
    'startDate': '06-26-2022',
    'endDate' : '07-26-2022',
    'beginTime' : '09:00',
    'endTime' : '14:30',
    'daysOfWeek' : '1,2,3,4,5',
    'excludeDates' : '07-04-2022',
    'resolution': 'hiRes',
}

# %%
do_junejuly23 = concat_frames_columns_do(requests.get(URL, params = params, headers = headers), 
                              requests.get(URL, params = params1, headers = headers), '06/26/22 - 07/26/22')
do_junejuly23.head(1)
# Out:
#                                             geometry fromStopId  \
# 0  LINESTRING (-86.75929 36.24254, -86.75955 36.2...   DOVDICWF
#
#                        fromStopName toStopId             toStopName  \
# 0  Doverside Dr & Dickerson Pike Wb    DWMRT  Dickerson Rd Wal Mart
#
#    pathLengthMeters  averageTravelSeconds  averageTravelSpeed  maxSecs  \
# 0             24.51              2.303622           10.639766   11.756
#
#    percent90Secs  ...  percent10Secs  minSecs  countForSegment  percent20Secs  \
# 0           2.69  ...          1.824    0.827              564           1.95
#
#                  dates        time  days_of_week  direction max_seg_count  \
# 0  06/26/22 - 07/26/22  9am-2:30pm           m-f   outbound           569
#
#   proportion_of_segments
# 0               0.991213
#
# [1 rows x 24 columns]

# %%
all_do_inschool = pd.concat([do_janfeb23, do_febmarch23, do_marchapr23, do_aprmay23])
all_do_inschool = all_do_inschool.reset_index()

all_do_inschool.head(1)
# Out:
#    index                                           geometry fromStopId  \
# 0      0  LINESTRING (-86.75929 36.24254, -86.75955 36.2...   DOVDICWF
#
#                        fromStopName toStopId             toStopName  \
# 0  Doverside Dr & Dickerson Pike Wb    DWMRT  Dickerson Rd Wal Mart
#
#    pathLengthMeters  averageTravelSeconds  averageTravelSpeed  maxSecs  ...  \
# 0             24.51              2.296379           10.673325    8.607  ...
#
#    percent10Secs  minSecs  countForSegment  percent20Secs  \
# 0          1.851    0.644              594          1.959
#
#                  dates        time  days_of_week  direction  max_seg_count  \
# 0  01/25/22 - 02/24/22  9am-2:30pm           m-f   outbound            609
#
#   proportion_of_segments
# 0               0.975369
#
# [1 rows x 25 columns]

# %%
all_do_summer = pd.concat([do_mayjune23, do_junejuly23])
all_do_summer = all_do_summer.reset_index()

all_do_summer.head(1)
# Out:
#    index                                           geometry fromStopId  \
# 0      0  LINESTRING (-86.75929 36.24254, -86.75955 36.2...   DOVDICWF
#
#                        fromStopName toStopId             toStopName  \
# 0  Doverside Dr & Dickerson Pike Wb    DWMRT  Dickerson Rd Wal Mart
#
#    pathLengthMeters  averageTravelSeconds  averageTravelSpeed  maxSecs  ...  \
# 0             24.51              2.306566           10.626186     5.98  ...
#
#    percent10Secs  minSecs  countForSegment  percent20Secs  \
# 0          1.829    1.589              567          1.955
#
#                  dates        time  days_of_week  direction  max_seg_count  \
# 0  05/26/22 - 06/25/22  9am-2:30pm           m-f   outbound            571
#
#   proportion_of_segments
# 0               0.992995
#
# [1 rows x 25 columns]

# %%
do_inschool = all_do_inschool.loc[all_do_inschool['proportion_of_segments'] >= 0.5]
do_inschool
# Out:
#       index                                           geometry fromStopId  \
# 0         0  LINESTRING (-86.75929 36.24254, -86.75955 36.2...   DOVDICWF
# 1         1  LINESTRING (-86.75656 36.24393, -86.75684 36.2...   DICMAPNF
# 3         3  LINESTRING (-86.77369 36.18411, -86.77367 36.1...   DICGRANN
# 4         4  LINESTRING (-86.76522 36.24183, -86.76495 36.2...   EAGDOVSN
# 7         7  LINESTRING (-86.76369 36.21581, -86.76362 36.2...   DICDELNN
# ...     ...                                                ...        ...
# 3557    878  LINESTRING (-86.77297 36.18957, -86.77294 36.1...   DICCLENN
# 3558    879  LINESTRING (-86.75955 36.24248, -86.75982 36.2...   DOVDICWF
# 3560    881  LINESTRING (-86.76039 36.22516, -86.76032 36.2...   DICSUNNF
# 3561    882  LINESTRING (-86.76523 36.21146, -86.76515 36.2...   DICQUENN
# 3562    883  LINESTRING (-86.77094 36.19806, -86.77084 36.1...   DICLUCNF
#
#                              fromStopName  toStopId  \
# 0        Doverside Dr & Dickerson Pike Wb     DWMRT
# 1     Dickerson Pike & Maplewood Trace Nb  DOVDICWF
# 3            Dickerson Pike & Grace St Nb  DICHANNN
# 4          Eaglewood Ln & Doverside Dr Sb     DWMRT
# 7               Dickerson & Dellway Dr Nb  DICLORNF
# ...                                   ...       ...
# 3557   N Dickerson Pike & Cleveland St Nb  DICEVANN
# 3558     Doverside Dr & Dickerson Pike Wb     DWMRT
# 3560        Dickerson Pike & Sunset Cr Nb  DICBENNF
# 3561        Dickerson Pike & Queen Ave Nb  DICDONNF
# 3562        Dickerson Pike & Lucile St Nb  DICMARNM
#
#                             toStopName  pathLengthMeters  \
# 0                Dickerson Rd Wal Mart            24.510
# 1     Doverside Dr & Dickerson Pike Wb            24.889
# 3     N Dickerson Pike & Hancock St Nb            23.765
# 4                Dickerson Rd Wal Mart            24.555
# 7     Dickerson Pike & Lorraine Ave Nb            23.891
# ...                                ...               ...
# 3557  Dickerson Pike & Evanston Ave Nb            23.618
# 3558             Dickerson Rd Wal Mart            24.510
# 3560  Dickerson Pike & Ben Allen Rd Nb            23.573
# 3561     Dickerson Pike & Donald St Nb            23.954
# 3562         Dickerson Pike & Marie Mb            24.309
#
#       averageTravelSeconds  averageTravelSpeed  maxSecs  ...  percent10Secs  \
# 0                 2.296379           10.673325    8.607  ...          1.851
# 1                 4.168339            5.970963   79.376  ...          2.549
# 3                 2.840996            8.365024  100.035  ...          1.484
# 4                 1.624731           15.113271    3.170  ...          1.391
# 7                 1.604847           14.886777    3.545  ...          1.294
# ...                    ...                 ...      ...  ...            ...
# 3557              2.026769           11.653030   14.437  ...          1.498
# 3558              2.447357           10.014885    9.167  ...          1.944
# 3560              1.882186           12.524267    7.363  ...          1.374
# 3561              1.904378           12.578385    8.874  ...          1.301
# 3562              2.034606           11.947768    7.019  ...          1.453
#
#       minSecs  countForSegment  percent20Secs                dates  \
# 0       0.644              594          1.959  01/25/22 - 02/24/22
# 1       1.368              595          2.825  01/25/22 - 02/24/22
# 3       1.221              494          1.594  01/25/22 - 02/24/22
# 4       0.273              305          1.468  01/25/22 - 02/24/22
# 7       1.033              562          1.375  01/25/22 - 02/24/22
# ...       ...              ...            ...                  ...
# 3557    0.992              562          1.561  04/27/22 - 05/26/22
# 3558    1.579              575          2.070  04/27/22 - 05/26/22
# 3560    1.162              452          1.459  04/27/22 - 05/26/22
# 3561    0.715              556          1.390  04/27/22 - 05/26/22
# 3562    1.221              510          1.552  04/27/22 - 05/26/22
#
#             time  days_of_week  direction  max_seg_count  \
# 0     9am-2:30pm           m-f   outbound            609
# 1     9am-2:30pm           m-f   outbound            609
# 3     9am-2:30pm           m-f   outbound            609
# 4     9am-2:30pm           m-f   outbound            609
# 7     9am-2:30pm           m-f   outbound            609
# ...          ...           ...        ...            ...
# 3557  9am-2:30pm           m-f   outbound            586
# 3558  9am-2:30pm           m-f   outbound            586
# 3560  9am-2:30pm           m-f   outbound            586
# 3561  9am-2:30pm           m-f   outbound            586
# 3562  9am-2:30pm           m-f   outbound            586
#
#      proportion_of_segments
# 0                  0.975369
# 1                  0.977011
# 3                  0.811166
# 4                  0.500821
# 7                  0.922824
# ...                     ...
# 3557               0.959044
# 3558               0.981229
# 3560               0.771331
# 3561               0.948805
# 3562               0.870307
#
# [2188 rows x 25 columns]

# %%
do_summer = all_do_summer.loc[all_do_summer['proportion_of_segments'] >= 0.5]
do_summer
# Out:
#       index                                           geometry fromStopId  \
# 0         0  LINESTRING (-86.75929 36.24254, -86.75955 36.2...   DOVDICWF
# 1         1  LINESTRING (-86.75656 36.24393, -86.75684 36.2...   DICMAPNF
# 3         3  LINESTRING (-86.77369 36.18411, -86.77367 36.1...   DICGRANN
# 6         6  LINESTRING (-86.76369 36.21581, -86.76362 36.2...   DICDELNN
# 8         8  LINESTRING (-86.77320 36.18809, -86.77317 36.1...   DICCLENN
# ...     ...                                                ...        ...
# 1763    878  LINESTRING (-86.77297 36.18957, -86.77294 36.1...   DICCLENN
# 1764    879  LINESTRING (-86.75955 36.24248, -86.75982 36.2...   DOVDICWF
# 1766    881  LINESTRING (-86.76523 36.21146, -86.76515 36.2...   DICQUENN
# 1767    882  LINESTRING (-86.76039 36.22516, -86.76032 36.2...   DICSUNNF
# 1768    883  LINESTRING (-86.77094 36.19806, -86.77084 36.1...   DICLUCNF
#
#                              fromStopName  toStopId  \
# 0        Doverside Dr & Dickerson Pike Wb     DWMRT
# 1     Dickerson Pike & Maplewood Trace Nb  DOVDICWF
# 3            Dickerson Pike & Grace St Nb  DICHANNN
# 6               Dickerson & Dellway Dr Nb  DICLORNF
# 8      N Dickerson Pike & Cleveland St Nb  DICEVANN
# ...                                   ...       ...
# 1763   N Dickerson Pike & Cleveland St Nb  DICEVANN
# 1764     Doverside Dr & Dickerson Pike Wb     DWMRT
# 1766        Dickerson Pike & Queen Ave Nb  DICDONNF
# 1767        Dickerson Pike & Sunset Cr Nb  DICBENNF
# 1768        Dickerson Pike & Lucile St Nb  DICMARNM
#
#                             toStopName  pathLengthMeters  \
# 0                Dickerson Rd Wal Mart            24.510
# 1     Doverside Dr & Dickerson Pike Wb            24.889
# 3     N Dickerson Pike & Hancock St Nb            23.765
# 6     Dickerson Pike & Lorraine Ave Nb            23.891
# 8     Dickerson Pike & Evanston Ave Nb            23.618
# ...                                ...               ...
# 1763  Dickerson Pike & Evanston Ave Nb            23.618
# 1764             Dickerson Rd Wal Mart            24.510
# 1766     Dickerson Pike & Donald St Nb            23.954
# 1767  Dickerson Pike & Ben Allen Rd Nb            23.573
# 1768         Dickerson Pike & Marie Mb            24.309
#
#       averageTravelSeconds  averageTravelSpeed  maxSecs  ...  percent10Secs  \
# 0                 2.306566           10.626186    5.980  ...          1.829
# 1                 3.798773            6.551852   23.775  ...          2.561
# 3                 2.996347            7.931324   25.702  ...          1.534
# 6                 1.668790           14.316361   11.939  ...          1.294
# 8                 2.037592           11.591133    4.133  ...          1.544
# ...                    ...                 ...      ...  ...            ...
# 1763              1.947472           12.127517    9.878  ...          1.459
# 1764              2.419565           10.129920   11.756  ...          1.917
# 1766              1.785161           13.418398    8.105  ...          1.287
# 1767              2.026147           11.634398   10.217  ...          1.352
# 1768              1.910998           12.720578    7.262  ...          1.396
#
#       minSecs  countForSegment  percent20Secs                dates  \
# 0       1.589              567          1.955  05/26/22 - 06/25/22
# 1       2.032              568          2.794  05/26/22 - 06/25/22
# 3       1.168              452          1.660  05/26/22 - 06/25/22
# 6       0.757              525          1.393  05/26/22 - 06/25/22
# 8       0.964              566          1.668  05/26/22 - 06/25/22
# ...       ...              ...            ...                  ...
# 1763    1.162              544          1.541  06/26/22 - 07/26/22
# 1764    0.827              565          2.027  06/26/22 - 07/26/22
# 1766    1.123              527          1.343  06/26/22 - 07/26/22
# 1767    0.786              408          1.416  06/26/22 - 07/26/22
# 1768    1.077              478          1.491  06/26/22 - 07/26/22
#
#             time  days_of_week  direction  max_seg_count  \
# 0     9am-2:30pm           m-f   outbound            571
# 1     9am-2:30pm           m-f   outbound            571
# 3     9am-2:30pm           m-f   outbound            571
# 6     9am-2:30pm           m-f   outbound            571
# 8     9am-2:30pm           m-f   outbound            571
# ...          ...           ...        ...            ...
# 1763  9am-2:30pm           m-f   outbound            569
# 1764  9am-2:30pm           m-f   outbound            569
# 1766  9am-2:30pm           m-f   outbound            569
# 1767  9am-2:30pm           m-f   outbound            569
# 1768  9am-2:30pm           m-f   outbound            569
#
#      proportion_of_segments
# 0                  0.992995
# 1                  0.994746
# 3                  0.791594
# 6                  0.919440
# 8                  0.991243
# ...                     ...
# 1763               0.956063
# 1764               0.992970
# 1766               0.926186
# 1767               0.717047
# 1768               0.840070
#
# [994 rows x 25 columns]

# %%
do_inschool.describe()
# Out:
#              index  pathLengthMeters  averageTravelSeconds  \
# count  2188.000000       2188.000000           2188.000000
# mean    436.022852         24.220035              3.786128
# std     264.792955          0.626338             15.715513
# min       0.000000         21.045000              1.436946
# 25%     200.000000         23.802000              1.822380
# 50%     425.000000         24.352000              2.149000
# 75%     664.250000         24.715000              2.882409
# max     907.000000         24.936000            453.503821
#
#        averageTravelSpeed      maxSecs  percent90Secs  percent80Secs  \
# count         2188.000000  2188.000000    2188.000000    2188.000000
# mean            10.560537    48.257633       7.130019       4.846590
# std              3.711730   160.733840      38.241088      29.979214
# min              0.054046     1.961000       1.625000       1.548000
# 25%              8.398117     5.270500       2.226750       1.994000
# 50%             11.281360    10.365500       2.843500       2.346500
# 75%             13.290729    35.305500       4.297750       3.235500
# max             16.932924  2474.046000     902.594000     840.385000
#
#        percent70Secs   medianSecs  percent30Secs  percent10Secs      minSecs  \
# count    2188.000000  2188.000000    2188.000000    2188.000000  2188.000000
# mean        3.864718     2.661733       1.936392       1.605635     1.159478
# std        25.955461    14.843507       2.550540       0.421356     0.273640
# min         1.496000     1.428000       1.335000       1.213000     0.273000
# 25%         1.853000     1.671750       1.526000       1.373000     1.044000
# 50%         2.106000     1.843000       1.661500       1.481000     1.152000
# 75%         2.744250     2.188875       1.918250       1.636000     1.255000
# max       780.032000   549.935000      97.801000       8.566000     3.088000
#
#        countForSegment  percent20Secs  max_seg_count  proportion_of_segments
# count      2188.000000    2188.000000    2188.000000             2188.000000
# mean        459.875229       1.749177     552.164534                0.833979
# std         117.235761       0.713175      60.411282                0.192975
# min         224.000000       1.285000     447.000000                0.500000
# 25%         346.000000       1.453000     556.000000                0.669025
# 50%         495.000000       1.576000     586.000000                0.957494
# 75%         567.000000       1.766250     609.000000                0.970917
# max         609.000000      21.021000     609.000000                1.000000

# %%
#. 2.57

# %% [markdown]
# eighty_percentile = np.percentile(do_inschool['percent20Secs'],80)
# eighty_percentile

# %% [markdown]
# percent20_inschool = do_inschool.loc[do_inschool['percent20Secs'] <  eighty_percentile]
# percent20_inschool

# %%
do_summer.describe()
# Out:
#             index  pathLengthMeters  averageTravelSeconds  averageTravelSpeed  \
# count  994.000000        994.000000            994.000000          994.000000
# mean   441.708249         24.222698              3.251423           10.599006
# std    262.016726          0.622507              4.964119            3.700260
# min      0.000000         21.045000              1.446198            0.312336
# 25%    217.000000         23.802000              1.828277            8.470773
# 50%    438.500000         24.352000              2.121802           11.348968
# 75%    668.000000         24.750000              2.839682           13.302439
# max    883.000000         24.936000             78.473287           16.719702
#
#            maxSecs  percent90Secs  percent80Secs  percent70Secs  medianSecs  \
# count   994.000000     994.000000     994.000000     994.000000  994.000000
# mean     48.866074       5.480551       3.733045       2.936615    2.203903
# std     187.704010      11.883704       6.089808       3.890426    1.777920
# min       2.266000       1.678000       1.580000       1.509000    1.417000
# 25%       5.338000       2.235250       1.997000       1.851000    1.667625
# 50%       9.732000       2.822500       2.318500       2.108000    1.840000
# 75%      34.282250       4.474000       3.248500       2.739500    2.211250
# max    2364.974000     257.603000      80.826000      66.596000   36.668500
#
#        percent30Secs  percent10Secs     minSecs  countForSegment  \
# count     994.000000     994.000000  994.000000       994.000000
# mean        1.855914       1.595714    1.150295       496.104628
# std         0.656385       0.375387    0.273868        99.747249
# min         1.324000       1.217000    0.668000       285.000000
# 25%         1.524000       1.376000    1.022000       455.250000
# 50%         1.656000       1.477000    1.142000       552.000000
# 75%         1.897750       1.617000    1.237000       559.000000
# max         9.823000       3.813000    2.633000       571.000000
#
#        percent20Secs  max_seg_count  proportion_of_segments
# count     994.000000     994.000000              994.000000
# mean        1.727207     570.104628                0.870264
# std         0.477031       0.995012                0.175174
# min         1.276000     569.000000                0.500876
# 25%         1.455000     569.000000                0.798063
# 50%         1.575000     571.000000                0.968476
# 75%         1.759250     571.000000                0.980668
# max         4.713000     571.000000                1.000000

# %%
#. 1.276000   3.276

# %%
slow_do_in_school = do_inschool.loc[do_inschool['percent20Secs'] > 2.57]

# %%
slow_do_in_school
# Out:
#       index                                           geometry fromStopId  \
# 1         1  LINESTRING (-86.75656 36.24393, -86.75684 36.2...   DICMAPNF
# 16       16  LINESTRING (-86.75658 36.24373, -86.75656 36.2...   DICMAPNF
# 36       36  LINESTRING (-86.75664 36.24351, -86.75658 36.2...   DICMAPNF
# 52       52  LINESTRING (-86.75669 36.24329, -86.75664 36.2...   DICMAPNF
# 93       93  LINESTRING (-86.77380 36.23048, -86.77397 36.2...   RICEWISM
# ...     ...                                                ...        ...
# 3481    802  LINESTRING (-86.76058 36.24306, -86.76082 36.2...   DOVDICWF
# 3492    813  LINESTRING (-86.76037 36.24292, -86.76058 36.2...   DOVDICWF
# 3519    840  LINESTRING (-86.77224 36.16923, -86.77226 36.1...    UNI2AEF
# 3543    864  LINESTRING (-86.77241 36.16894, -86.77217 36.1...    UNI2AEF
# 3556    877  LINESTRING (-86.77217 36.16904, -86.77224 36.1...    UNI2AEF
#
#                              fromStopName  toStopId  \
# 1     Dickerson Pike & Maplewood Trace Nb  DOVDICWF
# 16    Dickerson Pike & Maplewood Trace Nb  DOVDICWF
# 36    Dickerson Pike & Maplewood Trace Nb  DOVDICWF
# 52    Dickerson Pike & Maplewood Trace Nb  DOVDICWF
# 93         Richmond Hill Dr & Ewing Dr Sb  EWIEWIWN
# ...                                   ...       ...
# 3481     Doverside Dr & Dickerson Pike Wb     DWMRT
# 3492     Doverside Dr & Dickerson Pike Wb     DWMRT
# 3519                Union St & 2nd Ave Eb   1SWOONM
# 3543                Union St & 2nd Ave Eb   1SWOONM
# 3556                Union St & 2nd Ave Eb   1SWOONM
#
#                             toStopName  pathLengthMeters  \
# 1     Doverside Dr & Dickerson Pike Wb            24.889
# 16    Doverside Dr & Dickerson Pike Wb            24.889
# 36    Doverside Dr & Dickerson Pike Wb            24.889
# 52    Doverside Dr & Dickerson Pike Wb            24.889
# 93              Ewing Dr & Ewing Ln Wb            24.715
# ...                                ...               ...
# 3481             Dickerson Rd Wal Mart            24.510
# 3492             Dickerson Rd Wal Mart            24.510
# 3519         S 1st St & Woodland St Nb            24.428
# 3543         S 1st St & Woodland St Nb            24.428
# 3556         S 1st St & Woodland St Nb            24.428
#
#       averageTravelSeconds  averageTravelSpeed  maxSecs  ...  percent10Secs  \
# 1                 4.168339            5.970963   79.376  ...          2.549
# 16                6.806901            3.656436  117.230  ...          2.717
# 36               26.792965            0.928938  123.152  ...          2.968
# 52               14.827085            1.678617  111.247  ...          2.385
# 93                6.202824            3.984475   47.509  ...          2.672
# ...                    ...                 ...      ...  ...            ...
# 3481              3.108189            7.885621   18.503  ...          2.531
# 3492              2.949656            8.309444    9.167  ...          2.474
# 3519              3.597559            6.790160   10.357  ...          2.351
# 3543             16.549190            1.476084   78.928  ...          2.534
# 3556              4.588447            5.323806   49.919  ...          2.487
#
#       minSecs  countForSegment  percent20Secs                dates  \
# 1       1.368              595          2.825  01/25/22 - 02/24/22
# 16      1.368              595          3.083  01/25/22 - 02/24/22
# 36      1.368              596          3.499  01/25/22 - 02/24/22
# 52      1.368              597          2.912  01/25/22 - 02/24/22
# 93      2.007              307          2.921  01/25/22 - 02/24/22
# ...       ...              ...            ...                  ...
# 3481    2.028              576          2.675  04/27/22 - 05/26/22
# 3492    2.028              575          2.607  04/27/22 - 05/26/22
# 3519    1.598              562          2.585  04/27/22 - 05/26/22
# 3543    1.496              564          2.923  04/27/22 - 05/26/22
# 3556    1.598              562          2.795  04/27/22 - 05/26/22
#
#             time  days_of_week  direction  max_seg_count  \
# 1     9am-2:30pm           m-f   outbound            609
# 16    9am-2:30pm           m-f   outbound            609
# 36    9am-2:30pm           m-f   outbound            609
# 52    9am-2:30pm           m-f   outbound            609
# 93    9am-2:30pm           m-f   outbound            609
# ...          ...           ...        ...            ...
# 3481  9am-2:30pm           m-f   outbound            586
# 3492  9am-2:30pm           m-f   outbound            586
# 3519  9am-2:30pm           m-f   outbound            586
# 3543  9am-2:30pm           m-f   outbound            586
# 3556  9am-2:30pm           m-f   outbound            586
#
#      proportion_of_segments
# 1                  0.977011
# 16                 0.977011
# 36                 0.978654
# 52                 0.980296
# 93                 0.504105
# ...                     ...
# 3481               0.982935
# 3492               0.981229
# 3519               0.959044
# 3543               0.962457
# 3556               0.959044
#
# [180 rows x 25 columns]

# %%
#eighty_percentile

# %% [markdown]
# eighty_percentile_summer = np.percentile(am_summer['percent20Secs'],80)
# eighty_percentile_summer

# %% [markdown]
# percent20_am_summer= am_summer.loc[am_summer['percent20Secs'] < eighty_percentile_summer]
# percent20_am_summer

# %%
slow_do_summer = do_summer.loc[do_summer['percent20Secs'] > 3.276]
slow_do_summer
# Out:
#       index                                           geometry fromStopId  \
# 32       32  LINESTRING (-86.75664 36.24351, -86.75658 36.2...   DICMAPNF
# 133     133  LINESTRING (-86.76864 36.20549, -86.76857 36.2...   DICTRINM
# 334     334  LINESTRING (-86.77936 36.16673, -86.77924 36.1...    MCC4_24
# 338     338  LINESTRING (-86.77445 36.17653, -86.77444 36.1...   N1SOLDNM
# 351     351  LINESTRING (-86.77924 36.16653, -86.77911 36.1...    MCC4_24
# 447     447  LINESTRING (-86.77952 36.16684, -86.77936 36.1...    MCC4_24
# 764     764  LINESTRING (-86.76061 36.24400, -86.76054 36.2...   DOVDICWF
# 775     775  LINESTRING (-86.76069 36.24378, -86.76061 36.2...   DOVDICWF
# 917      32  LINESTRING (-86.75664 36.24351, -86.75658 36.2...   DICMAPNF
# 1016    131  LINESTRING (-86.76864 36.20549, -86.76857 36.2...   DICTRINM
# 1038    153  LINESTRING (-86.78132 36.23162, -86.78147 36.2...   EWIBRIWN
# 1219    334  LINESTRING (-86.77936 36.16673, -86.77924 36.1...    MCC4_24
# 1222    337  LINESTRING (-86.77445 36.17653, -86.77444 36.1...   N1SOLDNM
# 1236    351  LINESTRING (-86.77924 36.16653, -86.77911 36.1...    MCC4_24
# 1649    764  LINESTRING (-86.76061 36.24400, -86.76054 36.2...   DOVDICWF
# 1660    775  LINESTRING (-86.76069 36.24378, -86.76061 36.2...   DOVDICWF
#
#                              fromStopName  toStopId  \
# 32    Dickerson Pike & Maplewood Trace Nb  DOVDICWF
# 133      Dickerson Pike & E Trinity Ln Nb  DICTRINN
# 334              Central 4th Ave - Bay 24   UNI2AEF
# 338               N 1st St & Oldham St Nb  DICGRANN
# 351              Central 4th Ave - Bay 24   UNI2AEF
# 447              Central 4th Ave - Bay 24   UNI2AEF
# 764      Doverside Dr & Dickerson Pike Wb     DWMRT
# 775      Doverside Dr & Dickerson Pike Wb     DWMRT
# 917   Dickerson Pike & Maplewood Trace Nb  DOVDICWF
# 1016     Dickerson Pike & E Trinity Ln Nb  DICTRINN
# 1038      Ewing Dr & Brick Church Pike Wb  BRIRICNN
# 1219             Central 4th Ave - Bay 24   UNI2AEF
# 1222              N 1st St & Oldham St Nb  DICGRANN
# 1236             Central 4th Ave - Bay 24   UNI2AEF
# 1649     Doverside Dr & Dickerson Pike Wb     DWMRT
# 1660     Doverside Dr & Dickerson Pike Wb     DWMRT
#
#                                toStopName  pathLengthMeters  \
# 32       Doverside Dr & Dickerson Pike Wb            24.889
# 133       Dickerson Pike & E Trinty Ln Nb            23.807
# 334                 Union St & 2nd Ave Eb            24.929
# 338          Dickerson Pike & Grace St Nb            24.446
# 351                 Union St & 2nd Ave Eb            24.929
# 447                 Union St & 2nd Ave Eb            24.929
# 764                 Dickerson Rd Wal Mart            24.510
# 775                 Dickerson Rd Wal Mart            24.510
# 917      Doverside Dr & Dickerson Pike Wb            24.889
# 1016      Dickerson Pike & E Trinty Ln Nb            23.807
# 1038  Brick Church Pike & Richmond Hill D            24.936
# 1219                Union St & 2nd Ave Eb            24.929
# 1222         Dickerson Pike & Grace St Nb            24.446
# 1236                Union St & 2nd Ave Eb            24.929
# 1649                Dickerson Rd Wal Mart            24.510
# 1660                Dickerson Rd Wal Mart            24.510
#
#       averageTravelSeconds  averageTravelSpeed   maxSecs  ...  percent10Secs  \
# 32               25.509584            0.975673   115.688  ...          2.854
# 133              20.562063            1.157812   173.962  ...          2.513
# 334              11.645636            2.140630    56.041  ...          2.707
# 338              40.584687            0.602345   128.903  ...          2.749
# 351              15.134149            1.647202    63.064  ...          2.652
# 447               9.685946            2.573729    81.669  ...          2.508
# 764              78.473287            0.312336  2298.048  ...          3.813
# 775              65.107443            0.376455  2262.035  ...          3.178
# 917              24.274425            1.025318   109.277  ...          2.666
# 1016             21.033933            1.131838   144.530  ...          2.498
# 1038              6.570782            3.794982    36.868  ...          2.841
# 1219             11.636481            2.142314    69.814  ...          2.386
# 1222             43.367029            0.563700   137.516  ...          2.456
# 1236             14.843725            1.679430    69.814  ...          2.511
# 1649             66.439211            0.368909  2364.974  ...          3.636
# 1660             36.793311            0.666154  2364.835  ...          3.130
#
#       minSecs  countForSegment  percent20Secs                dates  \
# 32      0.847              567          3.448  05/26/22 - 06/25/22
# 133     1.426              557          3.649  05/26/22 - 06/25/22
# 334     0.725              569          3.653  05/26/22 - 06/25/22
# 338     1.356              556          4.713  05/26/22 - 06/25/22
# 351     0.725              569          3.521  05/26/22 - 06/25/22
# 447     0.725              569          3.605  05/26/22 - 06/25/22
# 764     2.472              348          4.320  05/26/22 - 06/25/22
# 775     2.447              521          3.631  05/26/22 - 06/25/22
# 917     1.525              560          3.330  06/26/22 - 07/26/22
# 1016    1.317              556          3.724  06/26/22 - 07/26/22
# 1038    1.335              285          3.279  06/26/22 - 07/26/22
# 1219    0.778              568          3.311  06/26/22 - 07/26/22
# 1222    1.365              554          4.613  06/26/22 - 07/26/22
# 1236    0.778              567          3.490  06/26/22 - 07/26/22
# 1649    2.633              341          4.211  06/26/22 - 07/26/22
# 1660    2.353              527          3.521  06/26/22 - 07/26/22
#
#             time  days_of_week  direction  max_seg_count  \
# 32    9am-2:30pm           m-f   outbound            571
# 133   9am-2:30pm           m-f   outbound            571
# 334   9am-2:30pm           m-f   outbound            571
# 338   9am-2:30pm           m-f   outbound            571
# 351   9am-2:30pm           m-f   outbound            571
# 447   9am-2:30pm           m-f   outbound            571
# 764   9am-2:30pm           m-f   outbound            571
# 775   9am-2:30pm           m-f   outbound            571
# 917   9am-2:30pm           m-f   outbound            569
# 1016  9am-2:30pm           m-f   outbound            569
# 1038  9am-2:30pm           m-f   outbound            569
# 1219  9am-2:30pm           m-f   outbound            569
# 1222  9am-2:30pm           m-f   outbound            569
# 1236  9am-2:30pm           m-f   outbound            569
# 1649  9am-2:30pm           m-f   outbound            569
# 1660  9am-2:30pm           m-f   outbound            569
#
#      proportion_of_segments
# 32                 0.992995
# 133                0.975482
# 334                0.996497
# 338                0.973730
# 351                0.996497
# 447                0.996497
# 764                0.609457
# 775                0.912434
# 917                0.984183
# 1016               0.977153
# 1038               0.500879
# 1219               0.998243
# 1222               0.973638
# 1236               0.996485
# 1649               0.599297
# 1660               0.926186
#
# [16 rows x 25 columns]

# %%
slow_do_sum_geojson = slow_do_summer['geometry'].to_json()

# %%
slow_do_in_school_geojson = slow_do_in_school['geometry'].to_json()

# %%
am23_map = folium.Map(location =  [36.19, -86.7775], zoom_start = 13)
style1 = {'color': 'red', 'weight': 10}
folium.GeoJson(slow_do_in_school_geojson, style_function=lambda x: style1).add_to(am23_map)
style2 = {'color' : 'blue', 'weight': 3 }
folium.GeoJson(slow_do_sum_geojson, style_function=lambda x: style2).add_to(am23_map)
am23_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css&quot;/&gt;
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cab84600416cb6ca2dfbc04177288bcb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cab84600416cb6ca2dfbc04177288bcb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_cab84600416cb6ca2dfbc04177288bcb = L.map(
#                 &quot;map_cab84600416cb6ca2dfbc04177288bcb&quot;,
#                 {
#                     center: [36.19, -86.7775],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6cadbcf3f4ce112a2519eca4c0edb41c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_cab84600416cb6ca2dfbc04177288bcb);
#
#
#         function geo_json_af2f7f5d7e3868f597da113b58b8a7f2_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;weight&quot;: 10};
#             }
#         }
#         function geo_json_af2f7f5d7e3868f597da113b58b8a7f2_onEachFeature(feature, layer) {
#             layer.on({
#                 click: function(e) {
#                     map_cab84600416cb6ca2dfbc04177288bcb.fitBounds(e.target.getBounds());
#                 }
#             });
#         };
#         var geo_json_af2f7f5d7e3868f597da113b58b8a7f2 = L.geoJson(null, {
#                 onEachFeature: geo_json_af2f7f5d7e3868f597da113b58b8a7f2_onEachFeature,
#
#                 style: geo_json_af2f7f5d7e3868f597da113b58b8a7f2_styler,
#         }).addTo(map_cab84600416cb6ca2dfbc04177288bcb);
#
#         function geo_json_af2f7f5d7e3868f597da113b58b8a7f2_add (data) {
#             geo_json_af2f7f5d7e3868f597da113b58b8a7f2.addData(data);
#         }
#             geo_json_af2f7f5d7e3868f597da113b58b8a7f2_add({&quot;bbox&quot;: [-86.78147347356244, 36.16552491289036, -86.75656464443999, 36.24526364104319], &quot;features&quot;: [{&quot;bbox&quot;: [-86.7568358659565, 36.243926062777, -86.75656464443999, 36.24397352654238], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-86.75656464443999, 36.243926062777], [-86.7568358659565, 36.24397352654238]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-86.75657921062708, 36.243728835640944, -86.75656464443999, 36.243926062777], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-86.75657921062708, 36.243728835640944], [-86.75656464443999, 36.243926062777]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;16&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-86.75663562767772, 36.24350967709806, -86.75657921062708, 36.243728835640944], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-86.75663562767772, 36.24350967709806], [-86.75657921062708, 36.243728835640944]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;36&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-86.75669204472837, 36.243290518555185, -86.75663562767772, 36.24350967709806], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-86.75669204472837, 36.243290518555185], [-86.75663562767772, 36.24350967709806]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;52&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-86.77397175922903, 36.23041428833337, -86.7738, 36.23048], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-86.7738, 36.23048], [-86.77397175922903, 36.23041428833337]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;93&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-86.76864325414681, 36.20549488838893, -86.7685697794851, 36.2057006174417], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-86.76864325414681, 36.20549488838893], [-86.7685697794851, 36.2057006174417]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;138&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-86.76869875166162, 36.20528582557912, -86.76864325414681, 36.20549488838893], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-86.76869875166162, 36.20528582557912], [-86.76864325414681, 36.20549488838893]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;148&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-86.78147347356244, 36.23161706139287, -86.7813198847367, 36.23172430702267], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-86.7813198847367, 36.23161706139287], [-86.78147347356244, 36.23172430702267]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;159&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-86.78104325649113, 36.231572353797624, -86.78076662824557, 36.23159470759524], &quot;geo

# %%
slow_do_summer.to_file("../data/slow_do_summer.geojson", driver = "GeoJSON")
# Out:
# /Users/patricklyons/opt/anaconda3/envs/geospatial/lib/python3.8/site-packages/geopandas/io/file.py:234: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   pd.Int64Index,

# %%
slow_do_in_school.to_file("../data/slow_do_in_school.geojson", driver = "GeoJSON")
