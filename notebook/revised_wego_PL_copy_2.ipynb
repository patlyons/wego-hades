# %%
import requests
import json
import pandas as pd
import numpy as np
from shapely.geometry import Point
import geopandas as gpd
import matplotlib.pyplot as plt
import folium
import re
from folium.plugins import MarkerCluster
from folium.plugins import FastMarkerCluster
import shapely.wkt

# %matplotlib inline

# %%
with open('../data/WeGo.json') as fi:
    credentials = json.load(fi)

# %%
Authorization = credentials['Authorization']

# %%
URL = 'https://api.goswift.ly/speed-map/nashville/route/23'


headers = {'Authorization': Authorization,
          'Content-Type': 'application/json'}

# %%
def concat_frames_columns_do(geo_response, response, date_range, time_range='9am-2:30pm', days='m-f', in_or_out='outbound'):
    """This function pulls in two API requests, puts one in a geodataframe the other in a dataframe and concats desired columns"""
    geo_df = gpd.GeoDataFrame.from_features(geo_response.json()['features'])
    res_df = pd.DataFrame(response.json()['data']['segments'])
    full_df = pd.concat([geo_df, res_df[['countForSegment', 'percent20Secs']]], axis = 1)
    full_df['dates'] = date_range
    full_df['time'] = time_range
    full_df['days_of_week'] = days
    full_df['direction']= in_or_out
    full_df['max_seg_count'] = full_df['countForSegment'].max()
    full_df['proportion_of_segments'] = full_df['countForSegment']/full_df['max_seg_count']
    return full_df

# %%
params = {
    'direction': '0',
    'startDate': '01-25-2022',
    'endDate' : '02-24-2022',
    'beginTime' : '09:00',
    'endTime' : '14:30',
    'daysOfWeek' : '1,2,3,4,5',
    'excludeDates': '02-18-2022',
    'format' : 'geojson',
    'resolution': 'hiRes',
}


params1 = {
    'direction': '0',
    'startDate': '01-25-2022',
    'endDate' : '02-24-2022',
    'beginTime' : '09:00',
    'endTime' : '14:30',
    'daysOfWeek' : '1,2,3,4,5',
    'excludeDates': '02-18-2022',
    'resolution': 'hiRes',
}

# %%
do_janfeb23 = concat_frames_columns_do(requests.get(URL, params = params, headers = headers), 
                              requests.get(URL, params = params1, headers = headers), '01/25/22 - 02/24/22')
do_janfeb23.head(1)
# Out:
#                                             geometry fromStopId  \
# 0  LINESTRING (-86.75929 36.24254, -86.75955 36.2...   DOVDICWF
#
#                        fromStopName toStopId             toStopName  \
# 0  Doverside Dr & Dickerson Pike Wb    DWMRT  Dickerson Rd Wal Mart
#
#    pathLengthMeters  averageTravelSeconds  averageTravelSpeed  maxSecs  \
# 0             24.51              2.296379           10.673325    8.607
#
#    percent90Secs  ...  percent10Secs  minSecs  countForSegment  percent20Secs  \
# 0          2.742  ...          1.851    0.644              594          1.959
#
#                  dates        time  days_of_week  direction max_seg_count  \
# 0  01/25/22 - 02/24/22  9am-2:30pm           m-f   outbound           609
#
#   proportion_of_segments
# 0               0.975369
#
# [1 rows x 24 columns]

# %%
params = {
    'direction': '0',
    'startDate': '02-25-2022',
    'endDate' : '03-26-2022',
    'beginTime' : '09:00',
    'endTime' : '14:30',
    'daysOfWeek' : '1,2,3,4,5',
    'excludeDates': '03-14-2022,03-15-2022,03-16-2022,03-17-2022,03-18-2022',
    'format' : 'geojson',
    'resolution': 'hiRes',
}


params1 = {
    'direction': '0',
    'startDate': '02-25-2022',
    'endDate' : '03-26-2022',
    'beginTime' : '09:00',
    'endTime' : '14:30',
    'daysOfWeek' : '1,2,3,4,5',
    'excludeDates': '03-14-2022,03-15-2022,03-16-2022,03-17-2022,03-18-2022',
    'resolution': 'hiRes',
}

# %%
do_febmarch23 = concat_frames_columns_do(requests.get(URL, params = params, headers = headers), 
                              requests.get(URL, params = params1, headers = headers), '02/25/22 - 03/26/22')
do_febmarch23.head(1)
# Out:
#                                             geometry fromStopId  \
# 0  LINESTRING (-86.75929 36.24254, -86.75955 36.2...   DOVDICWF
#
#                        fromStopName toStopId             toStopName  \
# 0  Doverside Dr & Dickerson Pike Wb    DWMRT  Dickerson Rd Wal Mart
#
#    pathLengthMeters  averageTravelSeconds  averageTravelSpeed  maxSecs  \
# 0             24.51              2.290051           10.702818   16.415
#
#    percent90Secs  ...  percent10Secs  minSecs  countForSegment  percent20Secs  \
# 0          2.688  ...          1.818    0.865              432           1.91
#
#                  dates        time  days_of_week  direction max_seg_count  \
# 0  02/25/22 - 03/26/22  9am-2:30pm           m-f   outbound           447
#
#   proportion_of_segments
# 0               0.966443
#
# [1 rows x 24 columns]

# %%
params = {
    'direction': '0',
    'startDate': '03-27-2022',
    'endDate' : '04-26-2022',
    'beginTime' : '09:00',
    'endTime' : '14:30',
    'daysOfWeek' : '1,2,3,4,5',
    'excludeDates': '04-14-2022,04-15-2022',
    'format' : 'geojson',
    'resolution': 'hiRes',
}


params1 = {
    'direction': '0',
    'startDate': '03-27-2022',
    'endDate' : '04-26-2022',
    'beginTime' : '09:00',
    'endTime' : '14:30',
    'daysOfWeek' : '1,2,3,4,5',
    'excludeDates': '04-14-2022,04-15-2022',
    'resolution': 'hiRes',
}

# %%
do_marchapr23 = concat_frames_columns_do(requests.get(URL, params = params, headers = headers), 
                              requests.get(URL, params = params1, headers = headers), '03/27/22 - 04/26/22')
do_marchapr23.head(1)
# Out:
#                                             geometry fromStopId  \
# 0  LINESTRING (-86.75929 36.24254, -86.75955 36.2...   DOVDICWF
#
#                        fromStopName toStopId             toStopName  \
# 0  Doverside Dr & Dickerson Pike Wb    DWMRT  Dickerson Rd Wal Mart
#
#    pathLengthMeters  averageTravelSeconds  averageTravelSpeed  maxSecs  \
# 0             24.51               2.32794           10.528622    9.319
#
#    percent90Secs  ...  percent10Secs  minSecs  countForSegment  percent20Secs  \
# 0          2.742  ...          1.884    1.249              551          2.007
#
#                  dates        time  days_of_week  direction max_seg_count  \
# 0  03/27/22 - 04/26/22  9am-2:30pm           m-f   outbound           556
#
#   proportion_of_segments
# 0               0.991007
#
# [1 rows x 24 columns]

# %%
params = {
    'direction': '0',
    'startDate': '04-27-2022',
    'endDate' : '05-26-2022',
    'beginTime' : '09:00',
    'endTime' : '14:30',
    'daysOfWeek' : '1,2,3,4,5',
    'format' : 'geojson',
    'resolution': 'hiRes',
}


params1 = {
    'direction': '0',
    'startDate': '04-27-2022',
    'endDate' : '05-26-2022',
    'beginTime' : '09:00',
    'endTime' : '14:30',
    'daysOfWeek' : '1,2,3,4,5',
    'resolution': 'hiRes',
}

# %%
do_aprmay23 = concat_frames_columns_do(requests.get(URL, params = params, headers = headers), 
                              requests.get(URL, params = params1, headers = headers), '04/27/22 - 05/26/22')
do_aprmay23.head(1)
# Out:
#                                             geometry fromStopId  \
# 0  LINESTRING (-86.75929 36.24254, -86.75955 36.2...   DOVDICWF
#
#                        fromStopName toStopId             toStopName  \
# 0  Doverside Dr & Dickerson Pike Wb    DWMRT  Dickerson Rd Wal Mart
#
#    pathLengthMeters  averageTravelSeconds  averageTravelSpeed  maxSecs  \
# 0             24.51              2.335774            10.49331    9.167
#
#    percent90Secs  ...  percent10Secs  minSecs  countForSegment  percent20Secs  \
# 0          2.884  ...           1.85    1.579              575          1.968
#
#                  dates        time  days_of_week  direction max_seg_count  \
# 0  04/27/22 - 05/26/22  9am-2:30pm           m-f   outbound           586
#
#   proportion_of_segments
# 0               0.981229
#
# [1 rows x 24 columns]

# %%
params = {
    'direction': '0',
    'startDate': '05-26-2022',
    'endDate' : '06-25-2022',
    'beginTime' : '09:00',
    'endTime' : '14:30',
    'daysOfWeek' : '1,2,3,4,5',
    'excludeDates' : '05-30-2022',
    'format' : 'geojson',
    'resolution': 'hiRes',
}


params1 = {
    'direction': '0',
    'startDate': '05-26-2022',
    'endDate' : '06-25-2022',
    'beginTime' : '09:00',
    'endTime' : '14:30',
    'daysOfWeek' : '1,2,3,4,5',
    'excludeDates' : '05-30-2022',
    'resolution': 'hiRes',
}

# %%
do_mayjune23 = concat_frames_columns_do(requests.get(URL, params = params, headers = headers), 
                              requests.get(URL, params = params1, headers = headers), '05/26/22 - 06/25/22')
do_mayjune23.head(1)
# Out:
#                                             geometry fromStopId  \
# 0  LINESTRING (-86.75929 36.24254, -86.75955 36.2...   DOVDICWF
#
#                        fromStopName toStopId             toStopName  \
# 0  Doverside Dr & Dickerson Pike Wb    DWMRT  Dickerson Rd Wal Mart
#
#    pathLengthMeters  averageTravelSeconds  averageTravelSpeed  maxSecs  \
# 0             24.51              2.306566           10.626186     5.98
#
#    percent90Secs  ...  percent10Secs  minSecs  countForSegment  percent20Secs  \
# 0          2.797  ...          1.829    1.589              567          1.955
#
#                  dates        time  days_of_week  direction max_seg_count  \
# 0  05/26/22 - 06/25/22  9am-2:30pm           m-f   outbound           571
#
#   proportion_of_segments
# 0               0.992995
#
# [1 rows x 24 columns]

# %%
params = {
    'direction': '0',
    'startDate': '06-26-2022',
    'endDate' : '07-26-2022',
    'beginTime' : '09:00',
    'endTime' : '14:30',
    'daysOfWeek' : '1,2,3,4,5',
    'excludeDates' : '07-04-2022',
    'format' : 'geojson',
    'resolution': 'hiRes',
}


params1 = {
    'direction': '0',
    'startDate': '06-26-2022',
    'endDate' : '07-26-2022',
    'beginTime' : '09:00',
    'endTime' : '14:30',
    'daysOfWeek' : '1,2,3,4,5',
    'excludeDates' : '07-04-2022',
    'resolution': 'hiRes',
}

# %%
do_junejuly23 = concat_frames_columns_do(requests.get(URL, params = params, headers = headers), 
                              requests.get(URL, params = params1, headers = headers), '06/26/22 - 07/26/22')
do_junejuly23.head(1)
# Out:
#                                             geometry fromStopId  \
# 0  LINESTRING (-86.75929 36.24254, -86.75955 36.2...   DOVDICWF
#
#                        fromStopName toStopId             toStopName  \
# 0  Doverside Dr & Dickerson Pike Wb    DWMRT  Dickerson Rd Wal Mart
#
#    pathLengthMeters  averageTravelSeconds  averageTravelSpeed  maxSecs  \
# 0             24.51              2.303622           10.639766   11.756
#
#    percent90Secs  ...  percent10Secs  minSecs  countForSegment  percent20Secs  \
# 0           2.69  ...          1.824    0.827              564           1.95
#
#                  dates        time  days_of_week  direction max_seg_count  \
# 0  06/26/22 - 07/26/22  9am-2:30pm           m-f   outbound           569
#
#   proportion_of_segments
# 0               0.991213
#
# [1 rows x 24 columns]

# %%
all_am_inschool = pd.concat([do_janfeb23, do_febmarch23, do_marchapr23, do_aprmay23])
all_am_inschool = all_am_inschool.reset_index()
all_am_inschool['set_count_proportion'] = all_am_inschool['countForSegment'] / all_am_inschool['max_seg_count']
all_am_inschool.head(1)
# Out:
#    index                                           geometry fromStopId  \
# 0      0  LINESTRING (-86.75929 36.24254, -86.75955 36.2...   DOVDICWF
#
#                        fromStopName toStopId             toStopName  \
# 0  Doverside Dr & Dickerson Pike Wb    DWMRT  Dickerson Rd Wal Mart
#
#    pathLengthMeters  averageTravelSeconds  averageTravelSpeed  maxSecs  ...  \
# 0             24.51              2.296379           10.673325    8.607  ...
#
#    minSecs  countForSegment  percent20Secs                dates        time  \
# 0    0.644              594          1.959  01/25/22 - 02/24/22  9am-2:30pm
#
#    days_of_week  direction  max_seg_count  proportion_of_segments  \
# 0           m-f   outbound            609                0.975369
#
#   set_count_proportion
# 0             0.975369
#
# [1 rows x 26 columns]

# %%
all_am_summer = pd.concat([do_mayjune23, do_junejuly23])
all_am_summer = all_am_summer.reset_index()
all_am_summer['set_count_proportion'] = all_am_summer['countForSegment'] / all_am_summer['max_seg_count']
all_am_summer.head(1)
# Out:
#    index                                           geometry fromStopId  \
# 0      0  LINESTRING (-86.75929 36.24254, -86.75955 36.2...   DOVDICWF
#
#                        fromStopName toStopId             toStopName  \
# 0  Doverside Dr & Dickerson Pike Wb    DWMRT  Dickerson Rd Wal Mart
#
#    pathLengthMeters  averageTravelSeconds  averageTravelSpeed  maxSecs  ...  \
# 0             24.51              2.306566           10.626186     5.98  ...
#
#    minSecs  countForSegment  percent20Secs                dates        time  \
# 0    1.589              567          1.955  05/26/22 - 06/25/22  9am-2:30pm
#
#    days_of_week  direction  max_seg_count  proportion_of_segments  \
# 0           m-f   outbound            571                0.992995
#
#   set_count_proportion
# 0             0.992995
#
# [1 rows x 26 columns]

# %%
am_inschool = all_am_inschool.loc[all_am_inschool['set_count_proportion'] >= 0.5]
am_inschool
# Out:
#       index                                           geometry fromStopId  \
# 0         0  LINESTRING (-86.75929 36.24254, -86.75955 36.2...   DOVDICWF
# 1         1  LINESTRING (-86.75656 36.24393, -86.75684 36.2...   DICMAPNF
# 3         3  LINESTRING (-86.77369 36.18411, -86.77367 36.1...   DICGRANN
# 4         4  LINESTRING (-86.76522 36.24183, -86.76495 36.2...   EAGDOVSN
# 7         7  LINESTRING (-86.76369 36.21581, -86.76362 36.2...   DICDELNN
# ...     ...                                                ...        ...
# 3557    878  LINESTRING (-86.77297 36.18957, -86.77294 36.1...   DICCLENN
# 3558    879  LINESTRING (-86.75955 36.24248, -86.75982 36.2...   DOVDICWF
# 3560    881  LINESTRING (-86.76039 36.22516, -86.76032 36.2...   DICSUNNF
# 3561    882  LINESTRING (-86.76523 36.21146, -86.76515 36.2...   DICQUENN
# 3562    883  LINESTRING (-86.77094 36.19806, -86.77084 36.1...   DICLUCNF
#
#                              fromStopName  toStopId  \
# 0        Doverside Dr & Dickerson Pike Wb     DWMRT
# 1     Dickerson Pike & Maplewood Trace Nb  DOVDICWF
# 3            Dickerson Pike & Grace St Nb  DICHANNN
# 4          Eaglewood Ln & Doverside Dr Sb     DWMRT
# 7               Dickerson & Dellway Dr Nb  DICLORNF
# ...                                   ...       ...
# 3557   N Dickerson Pike & Cleveland St Nb  DICEVANN
# 3558     Doverside Dr & Dickerson Pike Wb     DWMRT
# 3560        Dickerson Pike & Sunset Cr Nb  DICBENNF
# 3561        Dickerson Pike & Queen Ave Nb  DICDONNF
# 3562        Dickerson Pike & Lucile St Nb  DICMARNM
#
#                             toStopName  pathLengthMeters  \
# 0                Dickerson Rd Wal Mart            24.510
# 1     Doverside Dr & Dickerson Pike Wb            24.889
# 3     N Dickerson Pike & Hancock St Nb            23.765
# 4                Dickerson Rd Wal Mart            24.555
# 7     Dickerson Pike & Lorraine Ave Nb            23.891
# ...                                ...               ...
# 3557  Dickerson Pike & Evanston Ave Nb            23.618
# 3558             Dickerson Rd Wal Mart            24.510
# 3560  Dickerson Pike & Ben Allen Rd Nb            23.573
# 3561     Dickerson Pike & Donald St Nb            23.954
# 3562         Dickerson Pike & Marie Mb            24.309
#
#       averageTravelSeconds  averageTravelSpeed  maxSecs  ...  minSecs  \
# 0                 2.296379           10.673325    8.607  ...    0.644
# 1                 4.168339            5.970963   79.376  ...    1.368
# 3                 2.840996            8.365024  100.035  ...    1.221
# 4                 1.624731           15.113271    3.170  ...    0.273
# 7                 1.604847           14.886777    3.545  ...    1.033
# ...                    ...                 ...      ...  ...      ...
# 3557              2.026769           11.653030   14.437  ...    0.992
# 3558              2.447357           10.014885    9.167  ...    1.579
# 3560              1.882186           12.524267    7.363  ...    1.162
# 3561              1.904378           12.578385    8.874  ...    0.715
# 3562              2.034606           11.947768    7.019  ...    1.221
#
#       countForSegment  percent20Secs                dates        time  \
# 0                 594          1.959  01/25/22 - 02/24/22  9am-2:30pm
# 1                 595          2.825  01/25/22 - 02/24/22  9am-2:30pm
# 3                 494          1.594  01/25/22 - 02/24/22  9am-2:30pm
# 4                 305          1.468  01/25/22 - 02/24/22  9am-2:30pm
# 7                 562          1.375  01/25/22 - 02/24/22  9am-2:30pm
# ...               ...            ...                  ...         ...
# 3557              562          1.561  04/27/22 - 05/26/22  9am-2:30pm
# 3558              575          2.070  04/27/22 - 05/26/22  9am-2:30pm
# 3560              452          1.459  04/27/22 - 05/26/22  9am-2:30pm
# 3561              556          1.390  04/27/22 - 05/26/22  9am-2:30pm
# 3562              510          1.552  04/27/22 - 05/26/22  9am-2:30pm
#
#       days_of_week  direction  max_seg_count  proportion_of_segments  \
# 0              m-f   outbound            609                0.975369
# 1              m-f   outbound            609                0.977011
# 3              m-f   outbound            609                0.811166
# 4              m-f   outbound            609                0.500821
# 7              m-f   outbound            609                0.922824
# ...            ...        ...            ...                     ...
# 3557           m-f   outbound            586                0.959044
# 3558           m-f   outbound            586                0.981229
# 3560           m-f   outbound            586                0.771331
# 3561           m-f   outbound            586                0.948805
# 3562           m-f   outbound            586                0.870307
#
#      set_count_proportion
# 0                0.975369
# 1                0.977011
# 3                0.811166
# 4                0.500821
# 7                0.922824
# ...                   ...
# 3557             0.959044
# 3558             0.981229
# 3560             0.771331
# 3561             0.948805
# 3562             0.870307
#
# [2188 rows x 26 columns]

# %%
am_summer = all_am_summer.loc[all_am_summer['set_count_proportion'] >= 0.5]
am_summer
# Out:
#       index                                           geometry fromStopId  \
# 0         0  LINESTRING (-86.75929 36.24254, -86.75955 36.2...   DOVDICWF
# 1         1  LINESTRING (-86.75656 36.24393, -86.75684 36.2...   DICMAPNF
# 3         3  LINESTRING (-86.77369 36.18411, -86.77367 36.1...   DICGRANN
# 6         6  LINESTRING (-86.76369 36.21581, -86.76362 36.2...   DICDELNN
# 8         8  LINESTRING (-86.77320 36.18809, -86.77317 36.1...   DICCLENN
# ...     ...                                                ...        ...
# 1763    878  LINESTRING (-86.77297 36.18957, -86.77294 36.1...   DICCLENN
# 1764    879  LINESTRING (-86.75955 36.24248, -86.75982 36.2...   DOVDICWF
# 1766    881  LINESTRING (-86.76523 36.21146, -86.76515 36.2...   DICQUENN
# 1767    882  LINESTRING (-86.76039 36.22516, -86.76032 36.2...   DICSUNNF
# 1768    883  LINESTRING (-86.77094 36.19806, -86.77084 36.1...   DICLUCNF
#
#                              fromStopName  toStopId  \
# 0        Doverside Dr & Dickerson Pike Wb     DWMRT
# 1     Dickerson Pike & Maplewood Trace Nb  DOVDICWF
# 3            Dickerson Pike & Grace St Nb  DICHANNN
# 6               Dickerson & Dellway Dr Nb  DICLORNF
# 8      N Dickerson Pike & Cleveland St Nb  DICEVANN
# ...                                   ...       ...
# 1763   N Dickerson Pike & Cleveland St Nb  DICEVANN
# 1764     Doverside Dr & Dickerson Pike Wb     DWMRT
# 1766        Dickerson Pike & Queen Ave Nb  DICDONNF
# 1767        Dickerson Pike & Sunset Cr Nb  DICBENNF
# 1768        Dickerson Pike & Lucile St Nb  DICMARNM
#
#                             toStopName  pathLengthMeters  \
# 0                Dickerson Rd Wal Mart            24.510
# 1     Doverside Dr & Dickerson Pike Wb            24.889
# 3     N Dickerson Pike & Hancock St Nb            23.765
# 6     Dickerson Pike & Lorraine Ave Nb            23.891
# 8     Dickerson Pike & Evanston Ave Nb            23.618
# ...                                ...               ...
# 1763  Dickerson Pike & Evanston Ave Nb            23.618
# 1764             Dickerson Rd Wal Mart            24.510
# 1766     Dickerson Pike & Donald St Nb            23.954
# 1767  Dickerson Pike & Ben Allen Rd Nb            23.573
# 1768         Dickerson Pike & Marie Mb            24.309
#
#       averageTravelSeconds  averageTravelSpeed  maxSecs  ...  minSecs  \
# 0                 2.306566           10.626186    5.980  ...    1.589
# 1                 3.798773            6.551852   23.775  ...    2.032
# 3                 2.996347            7.931324   25.702  ...    1.168
# 6                 1.668790           14.316361   11.939  ...    0.757
# 8                 2.037592           11.591133    4.133  ...    0.964
# ...                    ...                 ...      ...  ...      ...
# 1763              1.947472           12.127517    9.878  ...    1.162
# 1764              2.419565           10.129920   11.756  ...    0.827
# 1766              1.785161           13.418398    8.105  ...    1.123
# 1767              2.026147           11.634398   10.217  ...    0.786
# 1768              1.910998           12.720578    7.262  ...    1.077
#
#       countForSegment  percent20Secs                dates        time  \
# 0                 567          1.955  05/26/22 - 06/25/22  9am-2:30pm
# 1                 568          2.794  05/26/22 - 06/25/22  9am-2:30pm
# 3                 452          1.660  05/26/22 - 06/25/22  9am-2:30pm
# 6                 525          1.393  05/26/22 - 06/25/22  9am-2:30pm
# 8                 566          1.668  05/26/22 - 06/25/22  9am-2:30pm
# ...               ...            ...                  ...         ...
# 1763              544          1.541  06/26/22 - 07/26/22  9am-2:30pm
# 1764              565          2.027  06/26/22 - 07/26/22  9am-2:30pm
# 1766              527          1.343  06/26/22 - 07/26/22  9am-2:30pm
# 1767              408          1.416  06/26/22 - 07/26/22  9am-2:30pm
# 1768              478          1.491  06/26/22 - 07/26/22  9am-2:30pm
#
#       days_of_week  direction  max_seg_count  proportion_of_segments  \
# 0              m-f   outbound            571                0.992995
# 1              m-f   outbound            571                0.994746
# 3              m-f   outbound            571                0.791594
# 6              m-f   outbound            571                0.919440
# 8              m-f   outbound            571                0.991243
# ...            ...        ...            ...                     ...
# 1763           m-f   outbound            569                0.956063
# 1764           m-f   outbound            569                0.992970
# 1766           m-f   outbound            569                0.926186
# 1767           m-f   outbound            569                0.717047
# 1768           m-f   outbound            569                0.840070
#
#      set_count_proportion
# 0                0.992995
# 1                0.994746
# 3                0.791594
# 6                0.919440
# 8                0.991243
# ...                   ...
# 1763             0.956063
# 1764             0.992970
# 1766             0.926186
# 1767             0.717047
# 1768             0.840070
#
# [994 rows x 26 columns]

# %%
eighty_percentile = np.percentile(am_inschool['percent20Secs'],80)
eighty_percentile
# Out:
# 1.8716000000000002

# %%
percent20_inschool = am_inschool.loc[am_inschool['percent20Secs'] <  eighty_percentile]
percent20_inschool
# Out:
#       index                                           geometry fromStopId  \
# 3         3  LINESTRING (-86.77369 36.18411, -86.77367 36.1...   DICGRANN
# 4         4  LINESTRING (-86.76522 36.24183, -86.76495 36.2...   EAGDOVSN
# 7         7  LINESTRING (-86.76369 36.21581, -86.76362 36.2...   DICDELNN
# 8         8  LINESTRING (-86.77063 36.23182, -86.77079 36.2...   CREPARWM
# 10       10  LINESTRING (-86.77320 36.18809, -86.77317 36.1...   DICCLENN
# ...     ...                                                ...        ...
# 3555    876  LINESTRING (-86.75973 36.22706, -86.75968 36.2...   DICBENNF
# 3557    878  LINESTRING (-86.77297 36.18957, -86.77294 36.1...   DICCLENN
# 3560    881  LINESTRING (-86.76039 36.22516, -86.76032 36.2...   DICSUNNF
# 3561    882  LINESTRING (-86.76523 36.21146, -86.76515 36.2...   DICQUENN
# 3562    883  LINESTRING (-86.77094 36.19806, -86.77084 36.1...   DICLUCNF
#
#                             fromStopName  toStopId  \
# 3           Dickerson Pike & Grace St Nb  DICHANNN
# 4         Eaglewood Ln & Doverside Dr Sb     DWMRT
# 7              Dickerson & Dellway Dr Nb  DICLORNF
# 8     CREPARWM (stop name not available)  CRERICWN
# 10    N Dickerson Pike & Cleveland St Nb  DICEVANN
# ...                                  ...       ...
# 3555    Dickerson Pike & Ben Allen Rd Nb  DICBRONF
# 3557  N Dickerson Pike & Cleveland St Nb  DICEVANN
# 3560       Dickerson Pike & Sunset Cr Nb  DICBENNF
# 3561       Dickerson Pike & Queen Ave Nb  DICDONNF
# 3562       Dickerson Pike & Lucile St Nb  DICMARNM
#
#                               toStopName  pathLengthMeters  \
# 3       N Dickerson Pike & Hancock St Nb            23.765
# 4                  Dickerson Rd Wal Mart            24.555
# 7       Dickerson Pike & Lorraine Ave Nb            23.891
# 8     Creekwood Dr & Richmond Hill Dr Wb            23.825
# 10      Dickerson Pike & Evanston Ave Nb            23.618
# ...                                  ...               ...
# 3555       Dickerson Pike & Broadmoor Nb            24.650
# 3557    Dickerson Pike & Evanston Ave Nb            23.618
# 3560    Dickerson Pike & Ben Allen Rd Nb            23.573
# 3561       Dickerson Pike & Donald St Nb            23.954
# 3562           Dickerson Pike & Marie Mb            24.309
#
#       averageTravelSeconds  averageTravelSpeed  maxSecs  ...  minSecs  \
# 3                 2.840996            8.365024  100.035  ...    1.221
# 4                 1.624731           15.113271    3.170  ...    0.273
# 7                 1.604847           14.886777    3.545  ...    1.033
# 8                 1.988643           11.980531    4.756  ...    1.318
# 10                2.026955           11.651961   10.645  ...    1.099
# ...                    ...                 ...      ...  ...      ...
# 3555              1.925955           12.798845   23.834  ...    1.225
# 3557              2.026769           11.653030   14.437  ...    0.992
# 3560              1.882186           12.524267    7.363  ...    1.162
# 3561              1.904378           12.578385    8.874  ...    0.715
# 3562              2.034606           11.947768    7.019  ...    1.221
#
#       countForSegment  percent20Secs                dates        time  \
# 3                 494          1.594  01/25/22 - 02/24/22  9am-2:30pm
# 4                 305          1.468  01/25/22 - 02/24/22  9am-2:30pm
# 7                 562          1.375  01/25/22 - 02/24/22  9am-2:30pm
# 8                 305          1.695  01/25/22 - 02/24/22  9am-2:30pm
# 10                594          1.611  01/25/22 - 02/24/22  9am-2:30pm
# ...               ...            ...                  ...         ...
# 3555              555          1.569  04/27/22 - 05/26/22  9am-2:30pm
# 3557              562          1.561  04/27/22 - 05/26/22  9am-2:30pm
# 3560              452          1.459  04/27/22 - 05/26/22  9am-2:30pm
# 3561              556          1.390  04/27/22 - 05/26/22  9am-2:30pm
# 3562              510          1.552  04/27/22 - 05/26/22  9am-2:30pm
#
#       days_of_week  direction  max_seg_count  proportion_of_segments  \
# 3              m-f   outbound            609                0.811166
# 4              m-f   outbound            609                0.500821
# 7              m-f   outbound            609                0.922824
# 8              m-f   outbound            609                0.500821
# 10             m-f   outbound            609                0.975369
# ...            ...        ...            ...                     ...
# 3555           m-f   outbound            586                0.947099
# 3557           m-f   outbound            586                0.959044
# 3560           m-f   outbound            586                0.771331
# 3561           m-f   outbound            586                0.948805
# 3562           m-f   outbound            586                0.870307
#
#      set_count_proportion
# 3                0.811166
# 4                0.500821
# 7                0.922824
# 8                0.500821
# 10               0.975369
# ...                   ...
# 3555             0.947099
# 3557             0.959044
# 3560             0.771331
# 3561             0.948805
# 3562             0.870307
#
# [1750 rows x 26 columns]

# %%
slow_am_in_school = am_inschool.loc[am_inschool['percent20Secs'] > 2.601]

# %%
slow_am_in_school.describe()
# Out:
#             index  pathLengthMeters  averageTravelSeconds  averageTravelSpeed  \
# count  170.000000        170.000000            170.000000          170.000000
# mean   436.188235         24.263788             18.096790            4.108525
# std    263.262013          1.161102             54.179624            2.238349
# min      1.000000         21.045000              2.949656            0.054046
# 25%    193.250000         24.428000              4.057327            2.129492
# 50%    395.000000         24.532500              5.584128            4.384235
# 75%    633.000000         24.929000             11.721108            5.839906
# max    887.000000         24.936000            453.503821            8.309444
#
#            maxSecs  percent90Secs  percent80Secs  percent70Secs  medianSecs  \
# count   170.000000     170.000000     170.000000     170.000000  170.000000
# mean    210.667612      42.858882      27.468165      20.974265   11.085997
# std     492.304794     130.971552     104.736436      91.492924   52.639666
# min       6.193000       3.421000       3.201000       3.063000    2.872000
# 25%      20.995750       5.405750       4.468250       4.058000    3.445000
# 50%      63.916000       8.389500       6.048000       4.999500    3.974000
# 75%     113.521750      24.619500      12.824000       8.184500    5.405250
# max    2474.046000     902.594000     840.385000     780.032000  549.935000
#
#        percent30Secs  percent10Secs     minSecs  countForSegment  \
# count     170.000000     170.000000  170.000000       170.000000
# mean        4.483159       2.696159    1.478294       461.341176
# std         8.715841       0.641637    0.560968       124.513068
# min         2.700000       2.093000    0.644000       231.000000
# 25%         2.983750       2.491250    0.928000       307.000000
# 50%         3.282000       2.584000    1.423500       537.000000
# 75%         3.588750       2.743750    1.967250       572.000000
# max        97.801000       8.566000    3.088000       608.000000
#
#        percent20Secs  max_seg_count  proportion_of_segments  \
# count     170.000000     170.000000              170.000000
# mean        3.257147     555.270588                0.833611
# std         1.818030      55.860326                0.213300
# min         2.607000     447.000000                0.500000
# 25%         2.769750     556.000000                0.517986
# 50%         2.898500     556.000000                0.967577
# 75%         3.184750     586.000000                0.984208
# max        21.021000     609.000000                1.000000
#
#        set_count_proportion
# count            170.000000
# mean               0.833611
# std                0.213300
# min                0.500000
# 25%                0.517986
# 50%                0.967577
# 75%                0.984208
# max                1.000000

# %%
slow_am_in_school = am_inschool.loc[am_inschool['percent20Secs'] > 3.201000]

# %%
slow_am_in_school
# Out:
#       index                                           geometry fromStopId  \
# 36       36  LINESTRING (-86.75664 36.24351, -86.75658 36.2...   DICMAPNF
# 138     138  LINESTRING (-86.76864 36.20549, -86.76857 36.2...   DICTRINM
# 197     197  LINESTRING (-86.78104 36.23159, -86.78132 36.2...   EWIBRIWN
# 336     336  LINESTRING (-86.77445 36.17653, -86.77444 36.1...   N1SOLDNM
# 762     762  LINESTRING (-86.76061 36.24400, -86.76054 36.2...   DOVDICWF
# 774     774  LINESTRING (-86.76069 36.24378, -86.76061 36.2...   DOVDICWF
# 921      36  LINESTRING (-86.75664 36.24351, -86.75658 36.2...   DICMAPNF
# 1028    143  LINESTRING (-86.76864 36.20549, -86.76857 36.2...   DICTRINM
# 1090    205  LINESTRING (-86.78104 36.23159, -86.78132 36.2...   EWIBRIWN
# 1241    356  LINESTRING (-86.77936 36.16673, -86.77924 36.1...    MCC4_24
# 1245    360  LINESTRING (-86.77445 36.17653, -86.77444 36.1...   N1SOLDNM
# 1258    373  LINESTRING (-86.77924 36.16653, -86.77911 36.1...    MCC4_24
# 1354    469  LINESTRING (-86.77952 36.16684, -86.77936 36.1...    MCC4_24
# 1671    786  LINESTRING (-86.76061 36.24400, -86.76054 36.2...   DOVDICWF
# 1683    798  LINESTRING (-86.76069 36.24378, -86.76061 36.2...   DOVDICWF
# 1826     32  LINESTRING (-86.75664 36.24351, -86.75658 36.2...   DICMAPNF
# 1879     85  LINESTRING (-86.77380 36.23048, -86.77397 36.2...   RICEWISM
# 1927    133  LINESTRING (-86.76864 36.20549, -86.76857 36.2...   DICTRINM
# 1947    153  LINESTRING (-86.78132 36.23162, -86.78147 36.2...   EWIBRIWN
# 1983    189  LINESTRING (-86.78104 36.23159, -86.78132 36.2...   EWIBRIWN
# 2128    334  LINESTRING (-86.77936 36.16673, -86.77924 36.1...    MCC4_24
# 2132    338  LINESTRING (-86.77445 36.17653, -86.77444 36.1...   N1SOLDNM
# 2145    351  LINESTRING (-86.77924 36.16653, -86.77911 36.1...    MCC4_24
# 2241    447  LINESTRING (-86.77952 36.16684, -86.77936 36.1...    MCC4_24
# 2526    732  LINESTRING (-86.76046 36.24442, -86.76038 36.2...      DWMRT
# 2537    743  LINESTRING (-86.76054 36.24421, -86.76046 36.2...      DWMRT
# 2558    764  LINESTRING (-86.76061 36.24400, -86.76054 36.2...   DOVDICWF
# 2569    775  LINESTRING (-86.76069 36.24378, -86.76061 36.2...   DOVDICWF
# 2575    781  LINESTRING (-86.76076 36.24357, -86.76069 36.2...   DOVDICWF
# 2711     32  LINESTRING (-86.75664 36.24351, -86.75658 36.2...   DICMAPNF
# 2809    130  LINESTRING (-86.76864 36.20549, -86.76857 36.2...   DICTRINM
# 2832    153  LINESTRING (-86.78132 36.23162, -86.78147 36.2...   EWIBRIWN
# 2868    189  LINESTRING (-86.78104 36.23159, -86.78132 36.2...   EWIBRIWN
# 3013    334  LINESTRING (-86.77936 36.16673, -86.77924 36.1...    MCC4_24
# 3016    337  LINESTRING (-86.77445 36.17653, -86.77444 36.1...   N1SOLDNM
# 3030    351  LINESTRING (-86.77924 36.16653, -86.77911 36.1...    MCC4_24
# 3125    446  LINESTRING (-86.77952 36.16684, -86.77936 36.1...    MCC4_24
# 3140    461  LINESTRING (-86.77814 36.16570, -86.77790 36.1...    MCC4_24
# 3443    764  LINESTRING (-86.76061 36.24400, -86.76054 36.2...   DOVDICWF
# 3454    775  LINESTRING (-86.76069 36.24378, -86.76061 36.2...   DOVDICWF
#
#                              fromStopName  toStopId  \
# 36    Dickerson Pike & Maplewood Trace Nb  DOVDICWF
# 138      Dickerson Pike & E Trinity Ln Nb  DICTRINN
# 197       Ewing Dr & Brick Church Pike Wb  BRIRICNN
# 336               N 1st St & Oldham St Nb  DICGRANN
# 762      Doverside Dr & Dickerson Pike Wb     DWMRT
# 774      Doverside Dr & Dickerson Pike Wb     DWMRT
# 921   Dickerson Pike & Maplewood Trace Nb  DOVDICWF
# 1028     Dickerson Pike & E Trinity Ln Nb  DICTRINN
# 1090      Ewing Dr & Brick Church Pike Wb  BRIRICNN
# 1241             Central 4th Ave - Bay 24   UNI2AEF
# 1245              N 1st St & Oldham St Nb  DICGRANN
# 1258             Central 4th Ave - Bay 24   UNI2AEF
# 1354             Central 4th Ave - Bay 24   UNI2AEF
# 1671     Doverside Dr & Dickerson Pike Wb     DWMRT
# 1683     Doverside Dr & Dickerson Pike Wb     DWMRT
# 1826  Dickerson Pike & Maplewood Trace Nb  DOVDICWF
# 1879       Richmond Hill Dr & Ewing Dr Sb  EWIEWIWN
# 1927     Dickerson Pike & E Trinity Ln Nb  DICTRINN
# 1947      Ewing Dr & Brick Church Pike Wb  BRIRICNN
# 1983      Ewing Dr & Brick Church Pike Wb  BRIRICNN
# 2128             Central 4th Ave - Bay 24   UNI2AEF
# 2132              N 1st St & Oldham St Nb  DICGRANN
# 2145             Central 4th Ave - Bay 24   UNI2AEF
# 2241             Central 4th Ave - Bay 24   UNI2AEF
# 2526                Dickerson Rd Wal Mart    DWMRTX
# 2537                Dickerson Rd Wal Mart    DWMRTX
# 2558     Doverside Dr & Dickerson Pike Wb     DWMRT
# 2569     Doverside Dr & Dickerson Pike Wb     DWMRT
# 2575     Doverside Dr & Dickerson Pike Wb     DWMRT
# 2711  Dickerson Pike & Maplewood Trace Nb  DOVDICWF
# 2809     Dickerson Pike & E Trinity Ln Nb  DICTRINN
# 2832      Ewing Dr & Brick Church Pike Wb  BRIRICNN
# 2868      Ewing Dr & Brick Church Pike Wb  BRIRICNN
# 3013             Central 4th Ave - Bay 24   UNI2AEF
# 3016              N 1st St & Oldham St Nb  DICGRANN
# 3030             Central 4th Ave - Bay 24   UNI2AEF
# 3125             Central 4th Ave - Bay 24   UNI2AEF
# 3140             Central 4th Ave - Bay 24   UNI2AEF
# 3443     Doverside Dr & Dickerson Pike Wb     DWMRT
# 3454     Doverside Dr & Dickerson Pike Wb     DWMRT
#
#                                toStopName  pathLengthMeters  \
# 36       Doverside Dr & Dickerson Pike Wb            24.889
# 138       Dickerson Pike & E Trinty Ln Nb            23.807
# 197   Brick Church Pike & Richmond Hill D            24.936
# 336          Dickerson Pike & Grace St Nb            24.446
# 762                 Dickerson Rd Wal Mart            24.510
# 774                 Dickerson Rd Wal Mart            24.510
# 921      Doverside Dr & Dickerson Pike Wb            24.889
# 1028      Dickerson Pike & E Trinty Ln Nb            23.807
# 1090  Brick Church Pike & Richmond Hill D            24.936
# 1241                Union St & 2nd Ave Eb            24.929
# 1245         Dickerson Pike & Grace St Nb            24.446
# 1258                Union St & 2nd Ave Eb            24.929
# 1354                Union St & 2nd Ave Eb            24.929
# 1671                Dickerson Rd Wal Mart            24.510
# 1683                Dickerson Rd Wal Mart            24.510
# 1826     Doverside Dr & Dickerson Pike Wb            24.889
# 1879               Ewing Dr & Ewing Ln Wb            24.715
# 1927      Dickerson Pike & E Trinty Ln Nb            23.807
# 1947  Brick Church Pike & Richmond Hill D            24.936
# 1983  Brick Church Pike & Richmond Hill D            24.936
# 2128                Union St & 2nd Ave Eb            24.929
# 2132         Dickerson Pike & Grace St Nb            24.446
# 2145                Union St & 2nd Ave Eb            24.929
# 2241                Union St & 2nd Ave Eb            24.929
# 2526            Dickerson Rd Walmart Exit            24.148
# 2537            Dickerson Rd Walmart Exit            24.148
# 2558                Dickerson Rd Wal Mart            24.510
# 2569                Dickerson Rd Wal Mart            24.510
# 2575                Dickerson Rd Wal Mart            24.510
# 2711     Doverside Dr & Dickerson Pike Wb            24.889
# 2809      Dickerson Pike & E Trinty Ln Nb            23.807
# 2832  Brick Church Pike & Richmond Hill D            24.936
# 2868  Brick Church Pike & Richmond Hill D            24.936
# 3013                Union St & 2nd Ave Eb            24.929
# 3016         Dickerson Pike & Grace St Nb            24.446
# 3030                Union St & 2nd Ave Eb            24.929
# 3125                Union St & 2nd Ave Eb            24.929
# 3140                Union St & 2nd Ave Eb            24.929
# 3443                Dickerson Rd Wal Mart            24.510
# 3454                Dickerson Rd Wal Mart            24.510
#
#       averageTravelSeconds  averageTravelSpeed   maxSecs  ...  minSecs  \
# 36               26.792965            0.928938   123.152  ...    1.368
# 138              22.364122            1.064518   210.971  ...    1.482
# 197              13.180702            1.891857   196.026  ...    1.567
# 336              40.019503            0.610852   122.108  ...    1.508
# 762             453.503821            0.054046  1076.626  ...    3.023
# 774              70.941579            0.345496  2188.116  ...    0.644
# 921              25.987519            0.957729   121.702  ...    1.686
# 1028             22.255783            1.069700   181.925  ...    1.486
# 1090             12.173307            2.048416   247.135  ...    1.667
# 1241             11.947870            2.086481    51.583  ...    0.931
# 1245             41.967900            0.582493   197.192  ...    1.370
# 1258             13.637413            1.827986    55.359  ...    0.931
# 1354              8.998780            2.770264    54.360  ...    0.931
# 1671            442.015105            0.055451  2055.030  ...    2.663
# 1683             50.938538            0.481168  1612.731  ...    2.203
# 1826             29.743022            0.836801   136.480  ...    1.470
# 1879              7.477404            3.305292    47.200  ...    2.247
# 1927             23.587175            1.009320   286.641  ...    1.513
# 1947              8.260874            3.018567    63.772  ...    0.865
# 1983             13.016196            1.915767   102.644  ...    0.865
# 2128             11.973849            2.081954    50.272  ...    0.866
# 2132             39.751916            0.614964   195.818  ...    1.152
# 2145             15.172331            1.643057   110.169  ...    0.866
# 2241             10.009977            2.490415   287.473  ...    0.866
# 2526             93.801270            0.257438  1042.492  ...    2.367
# 2537            279.272957            0.086467  1204.144  ...    2.550
# 2558            155.045864            0.158082  1818.357  ...    3.088
# 2569             44.613204            0.549389  2474.046  ...    1.209
# 2575             20.973854            1.168598  2325.453  ...    1.209
# 2711             27.680913            0.899139   145.695  ...    1.621
# 2809             19.764763            1.204517   178.861  ...    1.421
# 2832              7.618759            3.272974    61.700  ...    1.996
# 2868             11.040820            2.258528    69.143  ...    1.837
# 3013             12.313045            2.024601    49.317  ...    0.928
# 3016             40.153945            0.608807   189.268  ...    1.406
# 3030             15.893380            1.568515    51.821  ...    0.928
# 3125              9.886475            2.521526   124.977  ...    0.931
# 3140              5.293682            4.709199    20.403  ...    0.928
# 3443             83.275366            0.294325  1518.265  ...    2.780
# 3454             51.267664            0.478079  2250.318  ...    2.315
#
#       countForSegment  percent20Secs                dates        time  \
# 36                596          3.499  01/25/22 - 02/24/22  9am-2:30pm
# 138               596          3.603  01/25/22 - 02/24/22  9am-2:30pm
# 197               322          3.519  01/25/22 - 02/24/22  9am-2:30pm
# 336               585          4.153  01/25/22 - 02/24/22  9am-2:30pm
# 762               313         17.061  01/25/22 - 02/24/22  9am-2:30pm
# 774               454          3.941  01/25/22 - 02/24/22  9am-2:30pm
# 921               430          3.362  02/25/22 - 03/26/22  9am-2:30pm
# 1028              442          3.643  02/25/22 - 03/26/22  9am-2:30pm
# 1090              231          3.270  02/25/22 - 03/26/22  9am-2:30pm
# 1241              445          3.535  02/25/22 - 03/26/22  9am-2:30pm
# 1245              431          4.175  02/25/22 - 03/26/22  9am-2:30pm
# 1258              445          3.381  02/25/22 - 03/26/22  9am-2:30pm
# 1354              445          3.426  02/25/22 - 03/26/22  9am-2:30pm
# 1671              239         21.021  02/25/22 - 03/26/22  9am-2:30pm
# 1683              312          3.932  02/25/22 - 03/26/22  9am-2:30pm
# 1826              544          3.338  03/27/22 - 04/26/22  9am-2:30pm
# 1879              287          3.263  03/27/22 - 04/26/22  9am-2:30pm
# 1927              543          3.602  03/27/22 - 04/26/22  9am-2:30pm
# 1947              285          3.563  03/27/22 - 04/26/22  9am-2:30pm
# 1983              285          4.121  03/27/22 - 04/26/22  9am-2:30pm
# 2128              555          3.529  03/27/22 - 04/26/22  9am-2:30pm
# 2132              538          3.854  03/27/22 - 04/26/22  9am-2:30pm
# 2145              556          3.673  03/27/22 - 04/26/22  9am-2:30pm
# 2241              554          3.538  03/27/22 - 04/26/22  9am-2:30pm
# 2526              278          3.721  03/27/22 - 04/26/22  9am-2:30pm
# 2537              279          7.317  03/27/22 - 04/26/22  9am-2:30pm
# 2558              338          4.774  03/27/22 - 04/26/22  9am-2:30pm
# 2569              496          3.689  03/27/22 - 04/26/22  9am-2:30pm
# 2575              527          3.270  03/27/22 - 04/26/22  9am-2:30pm
# 2711              575          3.477  04/27/22 - 05/26/22  9am-2:30pm
# 2809              573          3.460  04/27/22 - 05/26/22  9am-2:30pm
# 2832              294          3.206  04/27/22 - 05/26/22  9am-2:30pm
# 2868              294          3.431  04/27/22 - 05/26/22  9am-2:30pm
# 3013              583          3.867  04/27/22 - 05/26/22  9am-2:30pm
# 3016              567          4.480  04/27/22 - 05/26/22  9am-2:30pm
# 3030              582          3.749  04/27/22 - 05/26/22  9am-2:30pm
# 3125              583          3.809  04/27/22 - 05/26/22  9am-2:30pm
# 3140              572          3.297  04/27/22 - 05/26/22  9am-2:30pm
# 3443              363          4.640  04/27/22 - 05/26/22  9am-2:30pm
# 3454              539          3.734  04/27/22 - 05/26/22  9am-2:30pm
#
#       days_of_week  direction  max_seg_count  proportion_of_segments  \
# 36             m-f   outbound            609                0.978654
# 138            m-f   outbound            609                0.978654
# 197            m-f   outbound            609                0.528736
# 336            m-f   outbound            609                0.960591
# 762            m-f   outbound            609                0.513957
# 774            m-f   outbound            609                0.745484
# 921            m-f   outbound            447                0.961969
# 1028           m-f   outbound            447                0.988814
# 1090           m-f   outbound            447                0.516779
# 1241           m-f   outbound            447                0.995526
# 1245           m-f   outbound            447                0.964206
# 1258           m-f   outbound            447                0.995526
# 1354           m-f   outbound            447                0.995526
# 1671           m-f   outbound            447                0.534676
# 1683           m-f   outbound            447                0.697987
# 1826           m-f   outbound            556                0.978417
# 1879           m-f   outbound            556                0.516187
# 1927           m-f   outbound            556                0.976619
# 1947           m-f   outbound            556                0.512590
# 1983           m-f   outbound            556                0.512590
# 2128           m-f   outbound            556                0.998201
# 2132           m-f   outbound            556                0.967626
# 2145           m-f   outbound            556                1.000000
# 2241           m-f   outbound            556                0.996403
# 2526           m-f   outbound            556                0.500000
# 2537           m-f   outbound            556                0.501799
# 2558           m-f   outbound            556                0.607914
# 2569           m-f   outbound            556                0.892086
# 2575           m-f   outbound            556                0.947842
# 2711           m-f   outbound            586                0.981229
# 2809           m-f   outbound            586                0.977816
# 2832           m-f   outbound            586                0.501706
# 2868           m-f   outbound            586                0.501706
# 3013           m-f   outbound            586                0.994881
# 3016           m-f   outbound            586                0.967577
# 3030           m-f   outbound            586                0.993174
# 3125           m-f   outbound            586                0.994881
# 3140           m-f   outbound            586                0.976109
# 3443           m-f   outbound            586                0.619454
# 3454           m-f   outbound            586                0.919795
#
#      set_count_proportion
# 36               0.978654
# 138              0.978654
# 197              0.528736
# 336              0.960591
# 762              0.513957
# 774              0.745484
# 921              0.961969
# 1028             0.988814
# 1090             0.516779
# 1241             0.995526
# 1245             0.964206
# 1258             0.995526
# 1354             0.995526
# 1671             0.534676
# 1683             0.697987
# 1826             0.978417
# 1879             0.516187
# 1927             0.976619
# 1947             0.512590
# 1983             0.512590
# 2128             0.998201
# 2132             0.967626
# 2145             1.000000
# 2241             0.996403
# 2526             0.500000
# 2537             0.501799
# 2558             0.607914
# 2569             0.892086
# 2575             0.947842
# 2711             0.981229
# 2809             0.977816
# 2832             0.501706
# 2868             0.501706
# 3013             0.994881
# 3016             0.967577
# 3030             0.993174
# 3125             0.994881
# 3140             0.976109
# 3443             0.619454
# 3454             0.919795
#
# [40 rows x 26 columns]

# %%
#eighty_percentile

# %% [markdown]
# eighty_percentile_summer = np.percentile(am_summer['percent20Secs'],80)
# eighty_percentile_summer

# %% [markdown]
# percent20_am_summer= am_summer.loc[am_summer['percent20Secs'] < eighty_percentile_summer]
# percent20_am_summer

# %%
slow__am_summer = am_summer.loc[am_summer['percent20Secs'] > 2.524]
slow__am_summer
# Out:
#       index                                           geometry fromStopId  \
# 1         1  LINESTRING (-86.75656 36.24393, -86.75684 36.2...   DICMAPNF
# 14       14  LINESTRING (-86.75658 36.24373, -86.75656 36.2...   DICMAPNF
# 32       32  LINESTRING (-86.75664 36.24351, -86.75658 36.2...   DICMAPNF
# 47       47  LINESTRING (-86.75669 36.24329, -86.75664 36.2...   DICMAPNF
# 85       85  LINESTRING (-86.77380 36.23048, -86.77397 36.2...   RICEWISM
# ...     ...                                                ...        ...
# 1698    813  LINESTRING (-86.76037 36.24292, -86.76058 36.2...   DOVDICWF
# 1710    825  LINESTRING (-86.76025 36.24273, -86.76037 36.2...   DOVDICWF
# 1725    840  LINESTRING (-86.77224 36.16923, -86.77226 36.1...    UNI2AEF
# 1749    864  LINESTRING (-86.77241 36.16894, -86.77217 36.1...    UNI2AEF
# 1762    877  LINESTRING (-86.77217 36.16904, -86.77224 36.1...    UNI2AEF
#
#                              fromStopName  toStopId  \
# 1     Dickerson Pike & Maplewood Trace Nb  DOVDICWF
# 14    Dickerson Pike & Maplewood Trace Nb  DOVDICWF
# 32    Dickerson Pike & Maplewood Trace Nb  DOVDICWF
# 47    Dickerson Pike & Maplewood Trace Nb  DOVDICWF
# 85         Richmond Hill Dr & Ewing Dr Sb  EWIEWIWN
# ...                                   ...       ...
# 1698     Doverside Dr & Dickerson Pike Wb     DWMRT
# 1710     Doverside Dr & Dickerson Pike Wb     DWMRT
# 1725                Union St & 2nd Ave Eb   1SWOONM
# 1749                Union St & 2nd Ave Eb   1SWOONM
# 1762                Union St & 2nd Ave Eb   1SWOONM
#
#                             toStopName  pathLengthMeters  \
# 1     Doverside Dr & Dickerson Pike Wb            24.889
# 14    Doverside Dr & Dickerson Pike Wb            24.889
# 32    Doverside Dr & Dickerson Pike Wb            24.889
# 47    Doverside Dr & Dickerson Pike Wb            24.889
# 85              Ewing Dr & Ewing Ln Wb            24.715
# ...                                ...               ...
# 1698             Dickerson Rd Wal Mart            24.510
# 1710             Dickerson Rd Wal Mart            24.510
# 1725         S 1st St & Woodland St Nb            24.428
# 1749         S 1st St & Woodland St Nb            24.428
# 1762         S 1st St & Woodland St Nb            24.428
#
#       averageTravelSeconds  averageTravelSpeed  maxSecs  ...  minSecs  \
# 1                 3.798773            6.551852   23.775  ...    2.032
# 14                6.527021            3.813225   96.920  ...    1.701
# 32               25.509584            0.975673  115.688  ...    0.847
# 47               16.485803            1.509723  115.069  ...    0.847
# 85                6.295262            3.925968   33.635  ...    2.359
# ...                    ...                 ...      ...  ...      ...
# 1698              2.987341            8.204621   13.025  ...    2.063
# 1710              2.891633            8.476179   13.025  ...    2.025
# 1725              3.869627            6.312753   76.296  ...    0.880
# 1749             16.354049            1.493697   95.266  ...    0.880
# 1762              4.500726            5.427569   20.984  ...    0.880
#
#       countForSegment  percent20Secs                dates        time  \
# 1                 568          2.794  05/26/22 - 06/25/22  9am-2:30pm
# 14                566          3.029  05/26/22 - 06/25/22  9am-2:30pm
# 32                567          3.448  05/26/22 - 06/25/22  9am-2:30pm
# 47                569          2.888  05/26/22 - 06/25/22  9am-2:30pm
# 85                286          3.101  05/26/22 - 06/25/22  9am-2:30pm
# ...               ...            ...                  ...         ...
# 1698              566          2.597  06/26/22 - 07/26/22  9am-2:30pm
# 1710              566          2.532  06/26/22 - 07/26/22  9am-2:30pm
# 1725              550          2.571  06/26/22 - 07/26/22  9am-2:30pm
# 1749              551          2.992  06/26/22 - 07/26/22  9am-2:30pm
# 1762              551          2.723  06/26/22 - 07/26/22  9am-2:30pm
#
#       days_of_week  direction  max_seg_count  proportion_of_segments  \
# 1              m-f   outbound            571                0.994746
# 14             m-f   outbound            571                0.991243
# 32             m-f   outbound            571                0.992995
# 47             m-f   outbound            571                0.996497
# 85             m-f   outbound            571                0.500876
# ...            ...        ...            ...                     ...
# 1698           m-f   outbound            569                0.994728
# 1710           m-f   outbound            569                0.994728
# 1725           m-f   outbound            569                0.966608
# 1749           m-f   outbound            569                0.968366
# 1762           m-f   outbound            569                0.968366
#
#      set_count_proportion
# 1                0.994746
# 14               0.991243
# 32               0.992995
# 47               0.996497
# 85               0.500876
# ...                   ...
# 1698             0.994728
# 1710             0.994728
# 1725             0.966608
# 1749             0.968366
# 1762             0.968366
#
# [92 rows x 26 columns]

# %%
slow__am_summer.describe()
# Out:
#             index  pathLengthMeters  averageTravelSeconds  averageTravelSpeed  \
# count   92.000000         92.000000             92.000000           92.000000
# mean   456.673913         24.403250             10.492037            4.501007
# std    268.942337          0.942217             13.656024            2.467559
# min      1.000000         21.045000              2.867703            0.312336
# 25%    271.750000         24.428000              3.746237            2.481704
# 50%    446.500000         24.510000              5.295419            4.707705
# 75%    764.000000         24.929000              9.845325            6.373704
# max    877.000000         24.936000             78.473287            8.518316
#
#            maxSecs  percent90Secs  percent80Secs  percent70Secs  medianSecs  \
# count    92.000000      92.000000      92.000000      92.000000   92.000000
# mean    211.577228      20.400185      12.146402       8.502609    4.980201
# std     556.644248      33.179856      15.931809      10.737537    4.888768
# min       5.751000       3.287000       3.104000       2.978000    2.762000
# 25%      23.077250       5.140000       4.154500       3.775250    3.205875
# 50%      67.732500       7.808500       5.470500       4.828500    3.869500
# 75%      97.679750      19.713750       9.690750       7.941250    4.913750
# max    2364.974000     257.603000      80.826000      66.596000   36.668500
#
#        percent30Secs  percent10Secs    minSecs  countForSegment  \
# count      92.000000      92.000000  92.000000        92.000000
# mean        3.432283       2.579380   1.456793       501.771739
# std         1.084919       0.262336   0.575664       110.774407
# min         2.599000       2.113000   0.725000       285.000000
# 25%         2.875250       2.458500   0.871750       550.000000
# 50%         3.154500       2.552000   1.403500       556.000000
# 75%         3.528000       2.696500   1.910500       566.000000
# max         9.823000       3.813000   2.633000       571.000000
#
#        percent20Secs  max_seg_count  proportion_of_segments  \
# count      92.000000      92.000000               92.000000
# mean        2.984185     570.195652                0.880111
# std         0.440658       0.986047                0.194623
# min         2.528000     569.000000                0.500876
# 25%         2.671750     569.000000                0.964536
# 50%         2.871000     571.000000                0.975439
# 75%         3.140250     571.000000                0.991243
# max         4.713000     571.000000                1.000000
#
#        set_count_proportion
# count             92.000000
# mean               0.880111
# std                0.194623
# min                0.500876
# 25%                0.964536
# 50%                0.975439
# 75%                0.991243
# max                1.000000

# %%
slow__am_summer = am_summer.loc[am_summer['percent20Secs'] > 3.104000]
slow__am_summer
# Out:
#       index                                           geometry fromStopId  \
# 32       32  LINESTRING (-86.75664 36.24351, -86.75658 36.2...   DICMAPNF
# 113     113  LINESTRING (-86.77310 36.23139, -86.77337 36.2...   CREPARWF
# 133     133  LINESTRING (-86.76864 36.20549, -86.76857 36.2...   DICTRINM
# 189     189  LINESTRING (-86.78104 36.23159, -86.78132 36.2...   EWIBRIWN
# 334     334  LINESTRING (-86.77936 36.16673, -86.77924 36.1...    MCC4_24
# 338     338  LINESTRING (-86.77445 36.17653, -86.77444 36.1...   N1SOLDNM
# 351     351  LINESTRING (-86.77924 36.16653, -86.77911 36.1...    MCC4_24
# 366     366  LINESTRING (-86.77911 36.16633, -86.77899 36.1...    MCC4_24
# 447     447  LINESTRING (-86.77952 36.16684, -86.77936 36.1...    MCC4_24
# 462     462  LINESTRING (-86.77814 36.16570, -86.77790 36.1...    MCC4_24
# 764     764  LINESTRING (-86.76061 36.24400, -86.76054 36.2...   DOVDICWF
# 775     775  LINESTRING (-86.76069 36.24378, -86.76061 36.2...   DOVDICWF
# 781     781  LINESTRING (-86.76076 36.24357, -86.76069 36.2...   DOVDICWF
# 917      32  LINESTRING (-86.75664 36.24351, -86.75658 36.2...   DICMAPNF
# 1016    131  LINESTRING (-86.76864 36.20549, -86.76857 36.2...   DICTRINM
# 1038    153  LINESTRING (-86.78132 36.23162, -86.78147 36.2...   EWIBRIWN
# 1219    334  LINESTRING (-86.77936 36.16673, -86.77924 36.1...    MCC4_24
# 1222    337  LINESTRING (-86.77445 36.17653, -86.77444 36.1...   N1SOLDNM
# 1236    351  LINESTRING (-86.77924 36.16653, -86.77911 36.1...    MCC4_24
# 1331    446  LINESTRING (-86.77952 36.16684, -86.77936 36.1...    MCC4_24
# 1346    461  LINESTRING (-86.77814 36.16570, -86.77790 36.1...    MCC4_24
# 1474    589  LINESTRING (-86.77839 36.16559, -86.77814 36.1...    MCC4_24
# 1649    764  LINESTRING (-86.76061 36.24400, -86.76054 36.2...   DOVDICWF
# 1660    775  LINESTRING (-86.76069 36.24378, -86.76061 36.2...   DOVDICWF
# 1666    781  LINESTRING (-86.76076 36.24357, -86.76069 36.2...   DOVDICWF
#
#                              fromStopName  toStopId  \
# 32    Dickerson Pike & Maplewood Trace Nb  DOVDICWF
# 113       Creekwood Dr & Park Creek Dr Wb  CRERICWN
# 133      Dickerson Pike & E Trinity Ln Nb  DICTRINN
# 189       Ewing Dr & Brick Church Pike Wb  BRIRICNN
# 334              Central 4th Ave - Bay 24   UNI2AEF
# 338               N 1st St & Oldham St Nb  DICGRANN
# 351              Central 4th Ave - Bay 24   UNI2AEF
# 366              Central 4th Ave - Bay 24   UNI2AEF
# 447              Central 4th Ave - Bay 24   UNI2AEF
# 462              Central 4th Ave - Bay 24   UNI2AEF
# 764      Doverside Dr & Dickerson Pike Wb     DWMRT
# 775      Doverside Dr & Dickerson Pike Wb     DWMRT
# 781      Doverside Dr & Dickerson Pike Wb     DWMRT
# 917   Dickerson Pike & Maplewood Trace Nb  DOVDICWF
# 1016     Dickerson Pike & E Trinity Ln Nb  DICTRINN
# 1038      Ewing Dr & Brick Church Pike Wb  BRIRICNN
# 1219             Central 4th Ave - Bay 24   UNI2AEF
# 1222              N 1st St & Oldham St Nb  DICGRANN
# 1236             Central 4th Ave - Bay 24   UNI2AEF
# 1331             Central 4th Ave - Bay 24   UNI2AEF
# 1346             Central 4th Ave - Bay 24   UNI2AEF
# 1474             Central 4th Ave - Bay 24   UNI2AEF
# 1649     Doverside Dr & Dickerson Pike Wb     DWMRT
# 1660     Doverside Dr & Dickerson Pike Wb     DWMRT
# 1666     Doverside Dr & Dickerson Pike Wb     DWMRT
#
#                                toStopName  pathLengthMeters  \
# 32       Doverside Dr & Dickerson Pike Wb            24.889
# 113    Creekwood Dr & Richmond Hill Dr Wb            24.923
# 133       Dickerson Pike & E Trinty Ln Nb            23.807
# 189   Brick Church Pike & Richmond Hill D            24.936
# 334                 Union St & 2nd Ave Eb            24.929
# 338          Dickerson Pike & Grace St Nb            24.446
# 351                 Union St & 2nd Ave Eb            24.929
# 366                 Union St & 2nd Ave Eb            24.929
# 447                 Union St & 2nd Ave Eb            24.929
# 462                 Union St & 2nd Ave Eb            24.929
# 764                 Dickerson Rd Wal Mart            24.510
# 775                 Dickerson Rd Wal Mart            24.510
# 781                 Dickerson Rd Wal Mart            24.510
# 917      Doverside Dr & Dickerson Pike Wb            24.889
# 1016      Dickerson Pike & E Trinty Ln Nb            23.807
# 1038  Brick Church Pike & Richmond Hill D            24.936
# 1219                Union St & 2nd Ave Eb            24.929
# 1222         Dickerson Pike & Grace St Nb            24.446
# 1236                Union St & 2nd Ave Eb            24.929
# 1331                Union St & 2nd Ave Eb            24.929
# 1346                Union St & 2nd Ave Eb            24.929
# 1474                Union St & 2nd Ave Eb            24.929
# 1649                Dickerson Rd Wal Mart            24.510
# 1660                Dickerson Rd Wal Mart            24.510
# 1666                Dickerson Rd Wal Mart            24.510
#
#       averageTravelSeconds  averageTravelSpeed   maxSecs  ...  minSecs  \
# 32               25.509584            0.975673   115.688  ...    0.847
# 113               6.476093            3.848462    76.042  ...    2.242
# 133              20.562063            1.157812   173.962  ...    1.426
# 189              12.272007            2.031941    81.528  ...    1.565
# 334              11.645636            2.140630    56.041  ...    0.725
# 338              40.584687            0.602345   128.903  ...    1.356
# 351              15.134149            1.647202    63.064  ...    0.725
# 366               5.373118            4.639578    48.893  ...    0.725
# 447               9.685946            2.573729    81.669  ...    0.725
# 462               5.376163            4.636950    49.222  ...    0.725
# 764              78.473287            0.312336  2298.048  ...    2.472
# 775              65.107443            0.376455  2262.035  ...    2.447
# 781              11.081678            2.211759  2217.723  ...    2.346
# 917              24.274425            1.025318   109.277  ...    1.525
# 1016             21.033933            1.131838   144.530  ...    1.317
# 1038              6.570782            3.794982    36.868  ...    1.335
# 1219             11.636481            2.142314    69.814  ...    0.778
# 1222             43.367029            0.563700   137.516  ...    1.365
# 1236             14.843725            1.679430    69.814  ...    0.778
# 1331              8.034157            3.102877    63.072  ...    0.778
# 1346              5.478400            4.550416    69.814  ...    0.778
# 1474              4.599504            5.419932    69.814  ...    0.778
# 1649             66.439211            0.368909  2364.974  ...    2.633
# 1660             36.793311            0.666154  2364.835  ...    2.353
# 1666             23.506463            1.042692  2278.328  ...    2.353
#
#       countForSegment  percent20Secs                dates        time  \
# 32                567          3.448  05/26/22 - 06/25/22  9am-2:30pm
# 113               291          3.138  05/26/22 - 06/25/22  9am-2:30pm
# 133               557          3.649  05/26/22 - 06/25/22  9am-2:30pm
# 189               291          3.183  05/26/22 - 06/25/22  9am-2:30pm
# 334               569          3.653  05/26/22 - 06/25/22  9am-2:30pm
# 338               556          4.713  05/26/22 - 06/25/22  9am-2:30pm
# 351               569          3.521  05/26/22 - 06/25/22  9am-2:30pm
# 366               568          3.148  05/26/22 - 06/25/22  9am-2:30pm
# 447               569          3.605  05/26/22 - 06/25/22  9am-2:30pm
# 462               558          3.195  05/26/22 - 06/25/22  9am-2:30pm
# 764               348          4.320  05/26/22 - 06/25/22  9am-2:30pm
# 775               521          3.631  05/26/22 - 06/25/22  9am-2:30pm
# 781               550          3.160  05/26/22 - 06/25/22  9am-2:30pm
# 917               560          3.330  06/26/22 - 07/26/22  9am-2:30pm
# 1016              556          3.724  06/26/22 - 07/26/22  9am-2:30pm
# 1038              285          3.279  06/26/22 - 07/26/22  9am-2:30pm
# 1219              568          3.311  06/26/22 - 07/26/22  9am-2:30pm
# 1222              554          4.613  06/26/22 - 07/26/22  9am-2:30pm
# 1236              567          3.490  06/26/22 - 07/26/22  9am-2:30pm
# 1331              567          3.202  06/26/22 - 07/26/22  9am-2:30pm
# 1346              560          3.256  06/26/22 - 07/26/22  9am-2:30pm
# 1474              564          3.144  06/26/22 - 07/26/22  9am-2:30pm
# 1649              341          4.211  06/26/22 - 07/26/22  9am-2:30pm
# 1660              527          3.521  06/26/22 - 07/26/22  9am-2:30pm
# 1666              553          3.139  06/26/22 - 07/26/22  9am-2:30pm
#
#       days_of_week  direction  max_seg_count  proportion_of_segments  \
# 32             m-f   outbound            571                0.992995
# 113            m-f   outbound            571                0.509632
# 133            m-f   outbound            571                0.975482
# 189            m-f   outbound            571                0.509632
# 334            m-f   outbound            571                0.996497
# 338            m-f   outbound            571                0.973730
# 351            m-f   outbound            571                0.996497
# 366            m-f   outbound            571                0.994746
# 447            m-f   outbound            571                0.996497
# 462            m-f   outbound            571                0.977233
# 764            m-f   outbound            571                0.609457
# 775            m-f   outbound            571                0.912434
# 781            m-f   outbound            571                0.963222
# 917            m-f   outbound            569                0.984183
# 1016           m-f   outbound            569                0.977153
# 1038           m-f   outbound            569                0.500879
# 1219           m-f   outbound            569                0.998243
# 1222           m-f   outbound            569                0.973638
# 1236           m-f   outbound            569                0.996485
# 1331           m-f   outbound            569                0.996485
# 1346           m-f   outbound            569                0.984183
# 1474           m-f   outbound            569                0.991213
# 1649           m-f   outbound            569                0.599297
# 1660           m-f   outbound            569                0.926186
# 1666           m-f   outbound            569                0.971880
#
#      set_count_proportion
# 32               0.992995
# 113              0.509632
# 133              0.975482
# 189              0.509632
# 334              0.996497
# 338              0.973730
# 351              0.996497
# 366              0.994746
# 447              0.996497
# 462              0.977233
# 764              0.609457
# 775              0.912434
# 781              0.963222
# 917              0.984183
# 1016             0.977153
# 1038             0.500879
# 1219             0.998243
# 1222             0.973638
# 1236             0.996485
# 1331             0.996485
# 1346             0.984183
# 1474             0.991213
# 1649             0.599297
# 1660             0.926186
# 1666             0.971880
#
# [25 rows x 26 columns]

# %%
slow_am_sum_geojson = slow__am_summer['geometry'].to_json()

# %%
slow_am_in_school_geojson = slow_am_in_school['geometry'].to_json()

# %%
am23_map = folium.Map(location =  [36.19, -86.7775], zoom_start = 13)
style1 = {'color': 'red', 'weight': 10}
folium.GeoJson(slow_am_in_school_geojson, style_function=lambda x: style1).add_to(am23_map)
style2 = {'color' : 'blue', 'weight': 3 }
folium.GeoJson(slow_am_sum_geojson, style_function=lambda x: style2).add_to(am23_map)
am23_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css&quot;/&gt;
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d102e758ff8daaee426467893aeca1b7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d102e758ff8daaee426467893aeca1b7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_d102e758ff8daaee426467893aeca1b7 = L.map(
#                 &quot;map_d102e758ff8daaee426467893aeca1b7&quot;,
#                 {
#                     center: [36.19, -86.7775],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4a6a3336e7df9b8b2eb0a14ce1fe1c24 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d102e758ff8daaee426467893aeca1b7);
#
#
#         function geo_json_a9b3b42390e25de93a35ccde50295321_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;weight&quot;: 10};
#             }
#         }
#         function geo_json_a9b3b42390e25de93a35ccde50295321_onEachFeature(feature, layer) {
#             layer.on({
#                 click: function(e) {
#                     map_d102e758ff8daaee426467893aeca1b7.fitBounds(e.target.getBounds());
#                 }
#             });
#         };
#         var geo_json_a9b3b42390e25de93a35ccde50295321 = L.geoJson(null, {
#                 onEachFeature: geo_json_a9b3b42390e25de93a35ccde50295321_onEachFeature,
#
#                 style: geo_json_a9b3b42390e25de93a35ccde50295321_styler,
#         }).addTo(map_d102e758ff8daaee426467893aeca1b7);
#
#         function geo_json_a9b3b42390e25de93a35ccde50295321_add (data) {
#             geo_json_a9b3b42390e25de93a35ccde50295321.addData(data);
#         }
#             geo_json_a9b3b42390e25de93a35ccde50295321_add({&quot;bbox&quot;: [-86.78147347356244, 36.16570313130661, -86.75657921062708, 36.244625101002015], &quot;features&quot;: [{&quot;bbox&quot;: [-86.75663562767772, 36.24350967709806, -86.75657921062708, 36.243728835640944], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-86.75663562767772, 36.24350967709806], [-86.75657921062708, 36.243728835640944]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;36&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-86.76864325414681, 36.20549488838893, -86.7685697794851, 36.2057006174417], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-86.76864325414681, 36.20549488838893], [-86.7685697794851, 36.2057006174417]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;138&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-86.7813198847367, 36.23159470759524, -86.78104325649113, 36.23161706139287], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-86.78104325649113, 36.23159470759524], [-86.7813198847367, 36.23161706139287]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;197&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-86.7744536705143, 36.17653026489532, -86.77444172670079, 36.17674917985069], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-86.7744536705143, 36.17653026489532], [-86.77444172670079, 36.17674917985069]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;336&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-86.76061407806333, 36.243996480876326, -86.76054043316807, 36.24420875145673], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-86.76061407806333, 36.243996480876326], [-86.76054043316807, 36.24420875145673]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;762&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-86.76068772295856, 36.243784210295914, -86.76061407806333, 36.243996480876326], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-86.76068772295856, 36.243784210295914], [-86.76061407806333, 36.243996480876326]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;774&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-86.75663562767772, 36.24350967709806, -86.75657921062708, 36.243728835640944], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-86.75663562767772, 36.24350967709806], [-86.75657921062708, 36.243728835640944]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;921&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-86.76864325414681, 36.20549488838893, -86.7685697794851, 36.2057006174417], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-86.76864325414681, 36.20549488838893], [-86.7685697794851, 36.2057006174417]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;1028&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-86.7813198847367, 36.23159470759524

# %%
# slow__am_summer.plot

# %%
#slow__am_summer['geometry'].to_json()

# %%
#map1 =   folium.Map(location = slow__am_summer['geometry'].to_json())

# %%
#. summer 2.582. in scool   2.6

# %%
# make a goole site
