# %% [markdown]
# conda space - activate geospatial then jupyter notebook

# %%
from shapely.geometry import Point
import pandas as pd
import geopandas as gpd
import requests
import json
import numpy as np
import matplotlib.pyplot as plt
import folium
import re
from folium.plugins import MarkerCluster
from folium.plugins import FastMarkerCluster

# %%
with open('../data/WeGo.json') as fi:
    credentials = json.load(fi)

# %%
Authorization = credentials['Authorization']

# %%
URL = 'https://api.goswift.ly/speed-map/nashville/route/23'

params = {
    'direction': '1',
    'startDate': '04-01-2022',
    'endDate' : '04-30-2022',
    'format' : 'geojson',
    'resolution': 'hiRes',
}

headers = {'Authorization': Authorization,
          'Content-Type': 'application/json'}

# %%
inbound23_response = requests.get(URL, params = params, headers = headers)

# %%
inbound23 = inbound23_response.json()['features']
inbound23
# Out:
# [{'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.78109586538973, 36.16730198529021],
#     [-86.78120719217702, 36.16711825084936]]},
#   'properties': {'fromStopId': 'UNI2AWN',
#    'fromStopName': 'Union St & 2nd Ave Wb',
#    'toStopId': 'MCC4_24',
#    'toStopName': 'Central 4th Ave - Bay 24',
#    'pathLengthMeters': 24.161,
#    'averageTravelSeconds': 4.601468,
#    'averageTravelSpeed': 5.250715641182336,
#    'maxSecs': 41.459,
#    'percent90Secs': 5.937,
#    'percent80Secs': 5.269,
#    'percent70Secs': 4.905,
#    'medianSecs': 4.305,
#    'percent30Secs': 3.774,
#    'percent10Secs': 3.139,
#    'minSecs': 1.54}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.76910864052451, 36.20380946030955],
#     [-86.76915296078676, 36.20359419046433]]},
#   'properties': {'fromStopId': 'DICWTRSF',
#    'fromStopName': 'Dickerson Pike & W Trinity Ln Sb',
#    'toStopId': 'DICGATSN',
# ...

# %%
inbound23_df = gpd.GeoDataFrame.from_features(inbound23)

# %%
params1 = {
    'direction': '1',
    'startDate': '04-01-2022',
    'endDate' : '04-30-2022',
    'resolution': 'hiRes',
}

# %%
inbound23_response1 = requests.get(URL, params = params1, headers = headers)

# %%
inbound23_1 = inbound23_response1.json()

# %%
inbound23_df1 = pd.DataFrame(inbound23_1['data']['segments'])
inbound23_df1 = inbound23_df1.drop(columns = ['pathLocs', 'toStop'])
inbound23_df1
# Out:
#      maxSecs  percent90Secs  percent80Secs  percent70Secs  medianSecs  \
# 0     41.459          5.937          5.269          4.905      4.3050
# 1     86.508          3.920          3.114          2.570      2.0495
# 2      7.557          2.412          2.253          2.146      1.9845
# 3     16.379          2.366          2.059          1.926      1.7660
# 4     24.096          3.403          2.445          2.138      1.8100
# ..       ...            ...            ...            ...         ...
# 487    9.030          2.005          1.839          1.720      1.5790
# 488   64.966          3.013          2.564          2.251      1.9130
# 489   16.277          3.345          2.594          2.237      1.8720
# 490   64.186          2.470          2.037          1.862      1.6905
# 491   18.884          2.388          2.046          1.901      1.6890
#
#      percent30Secs  percent20Secs  percent10Secs  minSecs  pathLengthMeters  \
# ...

# %%
URL2 = 'https://api.goswift.ly/speed-map/nashville/route/23'

params2 = {
    'direction': '1',
    'startDate': '04-01-2022',
    'endDate' : '04-30-2022',
    'format' : 'geojson',
}

headers = {'Authorization': Authorization,
          'Content-Type': 'application/json'}

# %%
inbound23_response_2 = requests.get(URL, params = params2, headers = headers)

# %%
inbound23_2 = inbound23_response.json()['features']
inbound23_2
# Out:
# [{'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.78109586538973, 36.16730198529021],
#     [-86.78120719217702, 36.16711825084936]]},
#   'properties': {'fromStopId': 'UNI2AWN',
#    'fromStopName': 'Union St & 2nd Ave Wb',
#    'toStopId': 'MCC4_24',
#    'toStopName': 'Central 4th Ave - Bay 24',
#    'pathLengthMeters': 24.161,
#    'averageTravelSeconds': 4.601468,
#    'averageTravelSpeed': 5.250715641182336,
#    'maxSecs': 41.459,
#    'percent90Secs': 5.937,
#    'percent80Secs': 5.269,
#    'percent70Secs': 4.905,
#    'medianSecs': 4.305,
#    'percent30Secs': 3.774,
#    'percent10Secs': 3.139,
#    'minSecs': 1.54}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.76910864052451, 36.20380946030955],
#     [-86.76915296078676, 36.20359419046433]]},
#   'properties': {'fromStopId': 'DICWTRSF',
#    'fromStopName': 'Dickerson Pike & W Trinity Ln Sb',
#    'toStopId': 'DICGATSN',
# ...

# %%
inbound23_df_2 = gpd.GeoDataFrame.from_features(inbound23_2)

# %%
params3 = {
    'direction': '1',
    'startDate': '04-01-2022',
    'endDate' : '04-30-2022',
    'resolution': 'hiRes',
}

# %%
inbound23_response2 = requests.get(URL, params = params3, headers = headers)

# %%
inbound23_2 = inbound23_response2.json()

# %%
inbound23_df2 = pd.DataFrame(inbound23_2['data']['segments'])
inbound23_df2 = inbound23_df2.drop(columns = ['pathLocs', 'toStop'])
inbound23_df2
# Out:
#      maxSecs  percent90Secs  percent80Secs  percent70Secs  medianSecs  \
# 0     41.459          5.937          5.269          4.905      4.3050
# 1     86.508          3.920          3.114          2.570      2.0495
# 2      7.557          2.412          2.253          2.146      1.9845
# 3     16.379          2.366          2.059          1.926      1.7660
# 4     24.096          3.403          2.445          2.138      1.8100
# ..       ...            ...            ...            ...         ...
# 487    9.030          2.005          1.839          1.720      1.5790
# 488   64.966          3.013          2.564          2.251      1.9130
# 489   16.277          3.345          2.594          2.237      1.8720
# 490   64.186          2.470          2.037          1.862      1.6905
# 491   18.884          2.388          2.046          1.901      1.6890
#
#      percent30Secs  percent20Secs  percent10Secs  minSecs  pathLengthMeters  \
# ...

# %%
inbound23_concat = pd.concat([inbound23_df1, inbound23_df2[['countForSegment', 'percent20Secs']]], axis = 1)
inbound23_concat
# Out:
#      maxSecs  percent90Secs  percent80Secs  percent70Secs  medianSecs  \
# 0     41.459          5.937          5.269          4.905      4.3050
# 1     86.508          3.920          3.114          2.570      2.0495
# 2      7.557          2.412          2.253          2.146      1.9845
# 3     16.379          2.366          2.059          1.926      1.7660
# 4     24.096          3.403          2.445          2.138      1.8100
# ..       ...            ...            ...            ...         ...
# 487    9.030          2.005          1.839          1.720      1.5790
# 488   64.966          3.013          2.564          2.251      1.9130
# 489   16.277          3.345          2.594          2.237      1.8720
# 490   64.186          2.470          2.037          1.862      1.6905
# 491   18.884          2.388          2.046          1.901      1.6890
#
#      percent30Secs  percent20Secs  percent10Secs  minSecs  pathLengthMeters  \
# ...

# %%
#start here

# %%
stsparams = {
    'direction': '1',
    'startDate': '04-01-2022',
    'endDate' : '04-30-2022',
    'format' : 'geojson',
}

# %%
inbound23_sts_response = requests.get(URL, params = stsparams, headers = headers)
inbound23_sts = inbound23_sts_response.json()['features']

# %%
inbound23_sts_df = gpd.GeoDataFrame.from_features(inbound23_sts)
inbound23_sts_df
# Out:
#                                              geometry fromStopId  \
# 0   LINESTRING (-86.76052 36.24425, -86.76033 36.2...      DWMRT
# 1   LINESTRING (-86.75708 36.24657, -86.75668 36.2...     DWMRTX
# 2   LINESTRING (-86.75659 36.24418, -86.75670 36.2...   DICDOVSN
# 3   LINESTRING (-86.75876 36.23278, -86.75944 36.2...   DICMAPSF
# 4   LINESTRING (-86.75944 36.22873, -86.75951 36.2...   DICEWISF
# ..                                                ...        ...
# 58                         POINT (-86.77457 36.17585)        NaN
# 59                         POINT (-86.77396 36.17282)        NaN
# 60                         POINT (-86.77282 36.16886)        NaN
# 61                         POINT (-86.77756 36.16621)        NaN
# 62                         POINT (-86.78140 36.16673)        NaN
#
#                            fromStopName                          fromStopLoc  \
# 0                 Dickerson Rd Wal Mart  {'lat': 36.24425, 'lon': -86.76052}
# ...

# %%
def concat_frames(geo_response, response):
    """This function pulls in two API requests, puts one in a geodataframe the other in a dataframe and concats desired columns"""
    geo_df = gpd.GeoDataFrame.from_features(geo_response.json()['features'])
    res_df = pd.DataFrame(response.json()['data']['segments'])
    full_df = pd.concat([geo_df, res_df[['countForSegment', 'percent20Secs']]], axis = 1)
    return full_df

# %%
params = {
    'direction': '1',
    'startDate': '01-25-2022',
    'beginTime' : '06:00',
    'daysOfWeek' : '1,5',
    'endDate' : '02-24-2022',
    'endTime' : '09:00',
    'format' : 'geojson',
    'resolution': 'hiRes',
    'excludeDates': '02-18-2022',
}


params1 = {
    'direction': '1',
    'startDate': '01-25-2022',
    'beginTime' : '06:00',
    'daysOfWeek' : '1,5',
    'endDate' : '02-24-2022',
    'endTime' : '09:00',
    'resolution': 'hiRes',
    'excludeDates': '02-18-2022',
}

# %%
jan_mf_concat_df = concat_frames(requests.get(URL, params = params, headers = headers), requests.get(URL, params = params1, headers = headers))

# %%
jan_mf_concat_df.head(1)
# Out:
#                                             geometry fromStopId  \
# 0  LINESTRING (-86.78110 36.16730, -86.78121 36.1...    UNI2AWN
#
#             fromStopName toStopId                toStopName  pathLengthMeters  \
# 0  Union St & 2nd Ave Wb  MCC4_24  Central 4th Ave - Bay 24            24.161
#
#    averageTravelSeconds  averageTravelSpeed  maxSecs  percent90Secs  \
# 0              4.393316            5.499491   10.765          5.623
#
#    percent80Secs  percent70Secs  medianSecs  percent30Secs  percent10Secs  \
# 0          5.213           4.84       4.429          3.756          3.221
#
#    minSecs  countForSegment  percent20Secs
# 0     1.52               98          3.455

# %%
params = {
    'direction': '1',
    'startDate': '01-25-2022',
    'beginTime' : '06:00',
    'daysOfWeek' : '2,3,4',
    'endDate' : '02-24-2022',
    'endTime' : '09:00',
    'format' : 'geojson',
    'resolution': 'hiRes',
    'excludeDates': '02-18-2022',
}


params1 = {
    'direction': '1',
    'startDate': '01-25-2022',
    'beginTime' : '06:00',
    'daysOfWeek' : '2,3,4',
    'endDate' : '02-24-2022',
    'endTime' : '09:00',
    'resolution': 'hiRes',
    'excludeDates': '02-18-2022',
}

# %%
jan_tuethurs_concat_df = concat_frames(requests.get(URL, params = params, headers = headers), requests.get(URL, params = params1, headers = headers))

# %%
jan_tuethurs_concat_df.head(1)
# Out:
#                                             geometry fromStopId  \
# 0  LINESTRING (-86.78110 36.16730, -86.78121 36.1...    UNI2AWN
#
#             fromStopName toStopId                toStopName  pathLengthMeters  \
# 0  Union St & 2nd Ave Wb  MCC4_24  Central 4th Ave - Bay 24            24.161
#
#    averageTravelSeconds  averageTravelSpeed  maxSecs  percent90Secs  \
# 0              4.457759            5.419988   26.752          5.472
#
#    percent80Secs  percent70Secs  medianSecs  percent30Secs  percent10Secs  \
# 0          5.119          4.852       4.245           3.74          3.293
#
#    minSecs  countForSegment  percent20Secs
# 0    0.341              216          3.547

# %%
params = {
    'direction': '1',
    'startDate': '02-25-2022',
    'beginTime' : '06:00',
    'daysOfWeek' : '2,3,4',
    'endDate' : '03-26-2022',
    'endTime' : '09:00',
    'format' : 'geojson',
    'resolution': 'hiRes',
    'excludedates': '03-14-2022,03-15-2022,03-16-2022,03-17-2022,03-18-2022',
}


params1 = {
    'direction': '1',
    'startDate': '02-25-2022',
    'beginTime' : '06:00',
    'daysOfWeek' : '2,3,4',
    'endDate' : '03-26-2022',
    'endTime' : '09:00',
    'resolution': 'hiRes',
    'excludedates': '03-14-2022,03-15-2022,03-16-2022,03-17-2022,03-18-2022',
}

# %%
feb_tuethurs_concat_df = concat_frames(requests.get(URL, params = params, headers = headers), requests.get(URL, params = params1, headers = headers))

# %%
feb_tuethurs_concat_df.head(1)
# Out:
#                                             geometry fromStopId  \
# 0  LINESTRING (-86.78110 36.16730, -86.78121 36.1...    UNI2AWN
#
#             fromStopName toStopId                toStopName  pathLengthMeters  \
# 0  Union St & 2nd Ave Wb  MCC4_24  Central 4th Ave - Bay 24            24.161
#
#    averageTravelSeconds  averageTravelSpeed  maxSecs  percent90Secs  \
# 0              4.243816            5.693225   13.499          5.361
#
#    percent80Secs  percent70Secs  medianSecs  percent30Secs  percent10Secs  \
# 0          5.046          4.666      4.0945          3.637          3.195
#
#    minSecs  countForSegment  percent20Secs
# 0    1.789              174          3.401

# %%
params = {
    'direction': '1',
    'startDate': '02-25-2022',
    'beginTime' : '06:00',
    'daysOfWeek' : '1,5',
    'endDate' : '03-24-2022',
    'endTime' : '09:00',
    'format' : 'geojson',
    'resolution': 'hiRes',
    'excludedates': '03-14-2022,03-15-2022,03-16-2022,03-17-2022,03-18-2022',
}


params1 = {
    'direction': '1',
    'startDate': '02-25-2022',
    'beginTime' : '06:00',
    'daysOfWeek' : '1,5',
    'endDate' : '03-24-2022',
    'endTime' : '09:00',
    'resolution': 'hiRes',
    'excludedates': '03-14-2022,03-15-2022,03-16-2022,03-17-2022,03-18-2022',
}

# %%
feb_mf_concat_df = concat_frames(requests.get(URL, params = params, headers = headers), requests.get(URL, params = params1, headers = headers))
feb_mf_concat_df.head(1)
# Out:
#                                             geometry fromStopId  \
# 0  LINESTRING (-86.78110 36.16730, -86.78121 36.1...    UNI2AWN
#
#             fromStopName toStopId                toStopName  pathLengthMeters  \
# 0  Union St & 2nd Ave Wb  MCC4_24  Central 4th Ave - Bay 24            24.161
#
#    averageTravelSeconds  averageTravelSpeed  maxSecs  percent90Secs  \
# 0              4.162181            5.804889    6.834          5.115
#
#    percent80Secs  percent70Secs  medianSecs  percent30Secs  percent10Secs  \
# 0          4.877          4.591      4.0515          3.688          3.146
#
#    minSecs  countForSegment  percent20Secs
# 0    2.527              116          3.481

# %%
params = {
    'direction': '1',
    'startDate': '03-27-2022',
    'beginTime' : '06:00',
    'daysOfWeek' : '2,3,4',
    'endDate' : '04-26-2022',
    'endTime' : '09:00',
    'format' : 'geojson',
    'resolution': 'hiRes',
    'excludedates': '04-14-2022,04-15-2022',
}


params1 = {
    'direction': '1',
    'startDate': '03-27-2022',
    'beginTime' : '06:00',
    'daysOfWeek' : '2,3,4',
    'endDate' : '04-26-2022',
    'endTime' : '09:00',
    'resolution': 'hiRes',
    'excludedates': '04-14-2022,04-15-2022',
}

# %%
mar_tuethurs_concat_df = concat_frames(requests.get(URL, params = params, headers = headers), requests.get(URL, params = params1, headers = headers))
mar_tuethurs_concat_df.head(1)
# Out:
#                                             geometry fromStopId  \
# 0  LINESTRING (-86.78110 36.16730, -86.78121 36.1...    UNI2AWN
#
#             fromStopName toStopId                toStopName  pathLengthMeters  \
# 0  Union St & 2nd Ave Wb  MCC4_24  Central 4th Ave - Bay 24            24.161
#
#    averageTravelSeconds  averageTravelSpeed  maxSecs  percent90Secs  \
# 0              4.430978            5.452747    19.34          5.259
#
#    percent80Secs  percent70Secs  medianSecs  percent30Secs  percent10Secs  \
# 0          5.028          4.824      4.3495          3.901          3.243
#
#    minSecs  countForSegment  percent20Secs
# 0    1.919              184          3.728

# %%
params = {
    'direction': '1',
    'startDate': '03-27-2022',
    'beginTime' : '06:00',
    'daysOfWeek' : '1,5',
    'endDate' : '04-26-2022',
    'endTime' : '09:00',
    'format' : 'geojson',
    'resolution': 'hiRes',
    'excludedates': '04-14-2022,04-15-2022',
}


params1 = {
    'direction': '1',
    'startDate': '03-27-2022',
    'beginTime' : '06:00',
    'daysOfWeek' : '1,5',
    'endDate' : '04-26-2022',
    'endTime' : '09:00',
    'resolution': 'hiRes',
    'excludedates': '04-14-2022,04-15-2022',
}

# %%
mar_mf_concat_df = concat_frames(requests.get(URL, params = params, headers = headers), requests.get(URL, params = params1, headers = headers))
mar_mf_concat_df.head(1)
# Out:
#                                             geometry fromStopId  \
# 0  LINESTRING (-86.78110 36.16730, -86.78121 36.1...    UNI2AWN
#
#             fromStopName toStopId                toStopName  pathLengthMeters  \
# 0  Union St & 2nd Ave Wb  MCC4_24  Central 4th Ave - Bay 24            24.161
#
#    averageTravelSeconds  averageTravelSpeed  maxSecs  percent90Secs  \
# 0              4.468031            5.407527   10.387          5.595
#
#    percent80Secs  percent70Secs  medianSecs  percent30Secs  percent10Secs  \
# 0          5.039          4.857       4.351          3.908          3.353
#
#    minSecs  countForSegment  percent20Secs
# 0    2.436              131          3.655

# %%
params = {
    'direction': '1',
    'startDate': '04-27-2022',
    'beginTime' : '06:00',
    'daysOfWeek' : '2,3,4',
    'endDate' : '05-25-2022',
    'endTime' : '09:00',
    'format' : 'geojson',
    'resolution': 'hiRes',
}


params1 = {
    'direction': '1',
    'startDate': '04-27-2022',
    'beginTime' : '06:00',
    'daysOfWeek' : '2,3,4',
    'endDate' : '05-25-2022',
    'endTime' : '09:00',
    'resolution': 'hiRes',
}

# %%
apr_tuethurs_concat_df = concat_frames(requests.get(URL, params = params, headers = headers), requests.get(URL, params = params1, headers = headers))
apr_tuethurs_concat_df.head(1)
# Out:
#                                             geometry fromStopId  \
# 0  LINESTRING (-86.78110 36.16730, -86.78121 36.1...    UNI2AWN
#
#             fromStopName toStopId                toStopName  pathLengthMeters  \
# 0  Union St & 2nd Ave Wb  MCC4_24  Central 4th Ave - Bay 24            24.161
#
#    averageTravelSeconds  averageTravelSpeed  maxSecs  percent90Secs  \
# 0              4.157226            5.811808     7.54          5.253
#
#    percent80Secs  percent70Secs  medianSecs  percent30Secs  percent10Secs  \
# 0          4.851          4.579       4.034          3.648          3.129
#
#    minSecs  countForSegment  percent20Secs
# 0    2.081              177          3.415

# %%
params = {
    'direction': '1',
    'startDate': '04-27-2022',
    'beginTime' : '06:00',
    'daysOfWeek' : '1,5',
    'endDate' : '05-25-2022',
    'endTime' : '09:00',
    'format' : 'geojson',
    'resolution': 'hiRes',
}


params1 = {
    'direction': '1',
    'startDate': '04-27-2022',
    'beginTime' : '06:00',
    'daysOfWeek' : '1,5',
    'endDate' : '05-25-2022',
    'endTime' : '09:00',
    'resolution': 'hiRes',
}

# %%
apr_mf_concat_df = concat_frames(requests.get(URL, params = params, headers = headers), requests.get(URL, params = params1, headers = headers))
apr_mf_concat_df.head(1)
# Out:
#                                             geometry fromStopId  \
# 0  LINESTRING (-86.78110 36.16730, -86.78121 36.1...    UNI2AWN
#
#             fromStopName toStopId                toStopName  pathLengthMeters  \
# 0  Union St & 2nd Ave Wb  MCC4_24  Central 4th Ave - Bay 24            24.161
#
#    averageTravelSeconds  averageTravelSpeed  maxSecs  percent90Secs  \
# 0              4.258436            5.673679   12.324          5.469
#
#    percent80Secs  percent70Secs  medianSecs  percent30Secs  percent10Secs  \
# 0          4.896          4.612       4.253          3.652          3.056
#
#    minSecs  countForSegment  percent20Secs
# 0    1.976              117          3.324

# %%
params = {
    'direction': '1',
    'startDate': '05-26-2022',
    'beginTime' : '06:00',
    'daysOfWeek' : '2,3,4',
    'endDate' : '06-25-2022',
    'endTime' : '09:00',
    'format' : 'geojson',
    'resolution': 'hiRes',
}


params1 = {
    'direction': '1',
    'startDate': '05-26-2022',
    'beginTime' : '06:00',
    'daysOfWeek' : '2,3,4',
    'endDate' : '06-25-2022',
    'endTime' : '09:00',
    'resolution': 'hiRes',
}

# %%
may_tuethur_concat_df = concat_frames(requests.get(URL, params = params, headers = headers), requests.get(URL, params = params1, headers = headers))
may_tuethur_concat_df.head(1)
# Out:
#                                             geometry fromStopId  \
# 0  LINESTRING (-86.78110 36.16730, -86.78121 36.1...    UNI2AWN
#
#             fromStopName toStopId                toStopName  pathLengthMeters  \
# 0  Union St & 2nd Ave Wb  MCC4_24  Central 4th Ave - Bay 24            24.161
#
#    averageTravelSeconds  averageTravelSpeed  maxSecs  percent90Secs  \
# 0               4.23778            5.701334   10.271          5.457
#
#    percent80Secs  percent70Secs  medianSecs  percent30Secs  percent10Secs  \
# 0          4.885          4.597       4.096           3.66          3.108
#
#    minSecs  countForSegment  percent20Secs
# 0    2.162              186          3.413

# %%
params = {
    'direction': '1',
    'startDate': '05-26-2022',
    'beginTime' : '06:00',
    'daysOfWeek' : '1,5',
    'endDate' : '06-25-2022',
    'endTime' : '09:00',
    'format' : 'geojson',
    'resolution': 'hiRes',
}


params1 = {
    'direction': '1',
    'startDate': '05-26-2022',
    'beginTime' : '06:00',
    'daysOfWeek' : '1,5',
    'endDate' : '06-25-2022',
    'endTime' : '09:00',
    'resolution': 'hiRes',
}

# %%
may_mf_concat_df = concat_frames(requests.get(URL, params = params, headers = headers), requests.get(URL, params = params1, headers = headers))
may_mf_concat_df.head(1)
# Out:
#                                             geometry fromStopId  \
# 0  LINESTRING (-86.78110 36.16730, -86.78121 36.1...    UNI2AWN
#
#             fromStopName toStopId                toStopName  pathLengthMeters  \
# 0  Union St & 2nd Ave Wb  MCC4_24  Central 4th Ave - Bay 24            24.161
#
#    averageTravelSeconds  averageTravelSpeed  maxSecs  percent90Secs  \
# 0              4.202854            5.748713    7.033          5.432
#
#    percent80Secs  percent70Secs  medianSecs  percent30Secs  percent10Secs  \
# 0          5.035          4.601       4.061          3.648          3.055
#
#    minSecs  countForSegment  percent20Secs
# 0    2.508              123          3.332

# %%
params = {
    'direction': '1',
    'startDate': '06-26-2022',
    'beginTime' : '06:00',
    'daysOfWeek' : '1,5',
    'endDate' : '07-26-2022',
    'endTime' : '09:00',
    'format' : 'geojson',
    'resolution': 'hiRes',
}


params1 = {
    'direction': '1',
    'startDate': '06-26-2022',
    'beginTime' : '06:00',
    'daysOfWeek' : '1,5',
    'endDate' : '07-26-2022',
    'endTime' : '09:00',
    'resolution': 'hiRes',
}

# %%
jun_tuethur_concat_df = concat_frames(requests.get(URL, params = params, headers = headers), requests.get(URL, params = params1, headers = headers))
jun_tuethur_concat_df.head(1)
# Out:
#                                             geometry fromStopId  \
# 0  LINESTRING (-86.78110 36.16730, -86.78121 36.1...    UNI2AWN
#
#             fromStopName toStopId                toStopName  pathLengthMeters  \
# 0  Union St & 2nd Ave Wb  MCC4_24  Central 4th Ave - Bay 24            24.161
#
#    averageTravelSeconds  averageTravelSpeed  maxSecs  percent90Secs  \
# 0              4.194608            5.760014   10.831          5.349
#
#    percent80Secs  percent70Secs  medianSecs  percent30Secs  percent10Secs  \
# 0          4.966          4.524       4.046          3.559          3.077
#
#    minSecs  countForSegment  percent20Secs
# 0    2.136              125          3.334

# %%
params = {
    'direction': '1',
    'startDate': '06-26-2022',
    'beginTime' : '06:00',
    'daysOfWeek' : '1,5',
    'endDate' : '07-26-2022',
    'endTime' : '09:00',
    'format' : 'geojson',
    'resolution': 'hiRes',
}


params1 = {
    'direction': '1',
    'startDate': '06-26-2022',
    'beginTime' : '06:00',
    'daysOfWeek' : '1,5',
    'endDate' : '07-26-2022',
    'endTime' : '09:00',
    'resolution': 'hiRes',
}

# %%
jun_mf_concat_df = concat_frames(requests.get(URL, params = params, headers = headers), requests.get(URL, params = params1, headers = headers))
jun_mf_concat_df.head(1)
# Out:
#                                             geometry fromStopId  \
# 0  LINESTRING (-86.78110 36.16730, -86.78121 36.1...    UNI2AWN
#
#             fromStopName toStopId                toStopName  pathLengthMeters  \
# 0  Union St & 2nd Ave Wb  MCC4_24  Central 4th Ave - Bay 24            24.161
#
#    averageTravelSeconds  averageTravelSpeed  maxSecs  percent90Secs  \
# 0              4.194608            5.760014   10.831          5.349
#
#    percent80Secs  percent70Secs  medianSecs  percent30Secs  percent10Secs  \
# 0          4.966          4.524       4.046          3.559          3.077
#
#    minSecs  countForSegment  percent20Secs
# 0    2.136              125          3.334

# %%
jan_tuethurs_concat_df['day_of_week'] = 'tue, wed, thur'

# %%
feb_tuethurs_concat_df['day_of_week'] = 'tue, wed, thur'

# %%
mar_tuethurs_concat_df['day_of_week'] = 'tue, wed, thur'

# %%
apr_tuethurs_concat_df['day_of_week'] = 'tue, wed, thur'

# %%
may_tuethur_concat_df['day_of_week'] = 'tue, wed, thur'

# %%
jun_tuethur_concat_df['day_of_week'] = 'tue, wed, thur'

# %%
jan_mf_concat_df['day_of_week'] = 'mon, fri'

# %%
feb_mf_concat_df['day_of_week'] = 'mon, fri'

# %%
mar_mf_concat_df['day_of_week'] = 'mon, fri'

# %%
apr_mf_concat_df['day_of_week'] = 'mon, fri'

# %%
may_mf_concat_df['day_of_week'] = 'mon, fri'

# %%
jun_mf_concat_df['day_of_week'] = 'mon, fri'

# %%
#times 6am - 9am AM Peak     9am-230pm Off Peak   230pm-6pm PM Peak   6pm-6am Overnight

# %%
#. all am summer     all am in school.          am in school

# %%
#. tues_thurs['dates'] = date range

# %%
#. df['max segment'] = df['countforsegmentmax']

# %%
jan_tuethurs_concat_df['dates'] = '01/25/2022-02/24/2022'

# %%
jan_mf_concat_df['dates'] = '01/25/2022-02/24/2022'

# %%
feb_tuethurs_concat_df['dates'] =  '2/25/2022-3/26/2022'

# %%
feb_mf_concat_df['dates'] =  '2/25/2022-3/26/2022'

# %%
mar_tuethurs_concat_df['dates'] = '03/27/2022-04/26/2022'

# %%
mar_mf_concat_df['dates']= '03/27/2022-04/26/2022'

# %%
apr_mf_concat_df['dates'] = '4/27/2022-5/25/2022'

# %%
apr_tuethurs_concat_df['dates'] = '4/27/2022-5/25/2022'

# %%
may_mf_concat_df['dates'] = '05/26/2022-06/25/2022'

# %%
may_tuethur_concat_df['dates'] = '05/26/2022-06/25/2022'

# %%
jun_tuethur_concat_df['dates'] = '06/26/2022-07/26/2022'

# %%
jun_mf_concat_df['dates'] = '06/26/2022-07/26/2022'

# %%
 #df['max segment'] = df['countforsegmentmax']

# %%
jan_tuethurs_concat_df['max_segment'] = jan_tuethurs_concat_df['countForSegment'].max()

# %%
jan_mf_concat_df['max_segment'] = jan_mf_concat_df['countForSegment'].max()

# %%
feb_tuethurs_concat_df['max_segment'] = feb_tuethurs_concat_df['countForSegment'].max()

# %%
feb_mf_concat_df['max_segment'] = feb_mf_concat_df['countForSegment'].max()

# %%
mar_tuethurs_concat_df['max_segment'] = mar_tuethurs_concat_df['countForSegment'].max()

# %%
mar_mf_concat_df['max_segment'] = mar_mf_concat_df['countForSegment'].max()

# %%
apr_mf_concat_df['max_segment'] = apr_mf_concat_df['countForSegment'].max()

# %%
apr_tuethurs_concat_df['max_segment'] = apr_tuethurs_concat_df['countForSegment'].max()

# %%
may_mf_concat_df['max_segment'] = may_mf_concat_df['countForSegment'].max()

# %%
may_tuethur_concat_df['max_segment'] = may_tuethur_concat_df['countForSegment'].max()

# %%
jun_tuethur_concat_df['max_segment'] = jun_tuethur_concat_df['countForSegment'].max()

# %%
jun_mf_concat_df['max_segment'] = jun_mf_concat_df['countForSegment'].max()

# %%
all_am_inschool = pd.concat([jan_tuethurs_concat_df, jan_mf_concat_df, feb_tuethurs_concat_df, feb_mf_concat_df, mar_tuethurs_concat_df, mar_mf_concat_df, apr_mf_concat_df, apr_tuethurs_concat_df])
all_am_inschool = all_am_inschool.reset_index(drop = True) 
all_am_inschool['set_count_proportion'] = all_am_inschool['countForSegment'] / all_am_inschool['max_segment']
all_am_inschool['direction'] = 'inbound'
all_am_inschool
# Out:
#                                                geometry fromStopId  \
# 0     LINESTRING (-86.78110 36.16730, -86.78121 36.1...    UNI2AWN
# 1     LINESTRING (-86.76911 36.20381, -86.76915 36.2...   DICWTRSF
# 2     LINESTRING (-86.77604 36.16755, -86.77628 36.1...   WOON1SWF
# 3     LINESTRING (-86.77385 36.17218, -86.77381 36.1...    1SOLDSM
# 4     LINESTRING (-86.77266 36.19266, -86.77269 36.1...   DICLIGSF
# ...                                                 ...        ...
# 3583  LINESTRING (-86.77063 36.19883, -86.77073 36.1...   DICGATSN
# 3584  LINESTRING (-86.76053 36.22505, -86.76060 36.2...   DICHILSF
# 3585  LINESTRING (-86.76968 36.20101, -86.76973 36.2...   DICWTRSF
# 3586  LINESTRING (-86.77093 36.19825, -86.77103 36.1...   DICMARSM
# 3587  LINESTRING (-86.76408 36.21494, -86.76416 36.2...   DICLORSN
#
#                           fromStopName  toStopId  \
# 0                Union St & 2nd Ave Wb   MCC4_24
# 1     Dickerson Pike & W Trinity Ln Sb  DICGATSN
# ...

# %%
all_am_suumer = pd.concat([may_mf_concat_df, may_tuethur_concat_df, jun_tuethur_concat_df, jun_mf_concat_df])
all_am_suumer = all_am_suumer.reset_index(drop = True) 
all_am_suumer['set_count_proportion'] = all_am_suumer['countForSegment'] / all_am_suumer['max_segment']
all_am_suumer['direction'] = 'inbound'
all_am_suumer
# Out:
#                                                geometry fromStopId  \
# 0     LINESTRING (-86.78110 36.16730, -86.78121 36.1...    UNI2AWN
# 1     LINESTRING (-86.76911 36.20381, -86.76915 36.2...   DICWTRSF
# 2     LINESTRING (-86.77604 36.16755, -86.77628 36.1...   WOON1SWF
# 3     LINESTRING (-86.77385 36.17218, -86.77381 36.1...    1SOLDSM
# 4     LINESTRING (-86.77266 36.19266, -86.77269 36.1...   DICLIGSF
# ...                                                 ...        ...
# 1775  LINESTRING (-86.77063 36.19883, -86.77073 36.1...   DICGATSN
# 1776  LINESTRING (-86.76053 36.22505, -86.76060 36.2...   DICHILSF
# 1777  LINESTRING (-86.76968 36.20101, -86.76973 36.2...   DICWTRSF
# 1778  LINESTRING (-86.76408 36.21494, -86.76416 36.2...   DICLORSN
# 1779  LINESTRING (-86.77093 36.19825, -86.77103 36.1...   DICMARSM
#
#                           fromStopName  toStopId  \
# 0                Union St & 2nd Ave Wb   MCC4_24
# 1     Dickerson Pike & W Trinity Ln Sb  DICGATSN
# ...

# %%
am_summer = all_am_suumer.loc[all_am_suumer['set_count_proportion'] >= .5]

# %%
am_summer
# Out:
#                                                geometry fromStopId  \
# 0     LINESTRING (-86.78110 36.16730, -86.78121 36.1...    UNI2AWN
# 1     LINESTRING (-86.76911 36.20381, -86.76915 36.2...   DICWTRSF
# 2     LINESTRING (-86.77604 36.16755, -86.77628 36.1...   WOON1SWF
# 3     LINESTRING (-86.77385 36.17218, -86.77381 36.1...    1SOLDSM
# 4     LINESTRING (-86.77266 36.19266, -86.77269 36.1...   DICLIGSF
# ...                                                 ...        ...
# 1775  LINESTRING (-86.77063 36.19883, -86.77073 36.1...   DICGATSN
# 1776  LINESTRING (-86.76053 36.22505, -86.76060 36.2...   DICHILSF
# 1777  LINESTRING (-86.76968 36.20101, -86.76973 36.2...   DICWTRSF
# 1778  LINESTRING (-86.76408 36.21494, -86.76416 36.2...   DICLORSN
# 1779  LINESTRING (-86.77093 36.19825, -86.77103 36.1...   DICMARSM
#
#                           fromStopName  toStopId  \
# 0                Union St & 2nd Ave Wb   MCC4_24
# 1     Dickerson Pike & W Trinity Ln Sb  DICGATSN
# ...

# %%
all_inschool = all_am_inschool.loc[all_am_inschool['set_count_proportion'] >= .5]

# %%
all_inschool
# Out:
#                                                geometry fromStopId  \
# 0     LINESTRING (-86.78110 36.16730, -86.78121 36.1...    UNI2AWN
# 1     LINESTRING (-86.76911 36.20381, -86.76915 36.2...   DICWTRSF
# 2     LINESTRING (-86.77604 36.16755, -86.77628 36.1...   WOON1SWF
# 3     LINESTRING (-86.77385 36.17218, -86.77381 36.1...    1SOLDSM
# 4     LINESTRING (-86.77266 36.19266, -86.77269 36.1...   DICLIGSF
# ...                                                 ...        ...
# 3583  LINESTRING (-86.77063 36.19883, -86.77073 36.1...   DICGATSN
# 3584  LINESTRING (-86.76053 36.22505, -86.76060 36.2...   DICHILSF
# 3585  LINESTRING (-86.76968 36.20101, -86.76973 36.2...   DICWTRSF
# 3586  LINESTRING (-86.77093 36.19825, -86.77103 36.1...   DICMARSM
# 3587  LINESTRING (-86.76408 36.21494, -86.76416 36.2...   DICLORSN
#
#                           fromStopName  toStopId  \
# 0                Union St & 2nd Ave Wb   MCC4_24
# 1     Dickerson Pike & W Trinity Ln Sb  DICGATSN
# ...

# %%
import shapely.wkt

# %%
list(all_inschool['geometry'])
# Out:
# ...
#  ...]

# %%
all_inschool['geometry'] #.to_frame()
# Out:
# 0       LINESTRING (-86.78110 36.16730, -86.78121 36.1...
# 1       LINESTRING (-86.76911 36.20381, -86.76915 36.2...
# 2       LINESTRING (-86.77604 36.16755, -86.77628 36.1...
# 3       LINESTRING (-86.77385 36.17218, -86.77381 36.1...
# 4       LINESTRING (-86.77266 36.19266, -86.77269 36.1...
#                               ...
# 3583    LINESTRING (-86.77063 36.19883, -86.77073 36.1...
# 3584    LINESTRING (-86.76053 36.22505, -86.76060 36.2...
# 3585    LINESTRING (-86.76968 36.20101, -86.76973 36.2...
# 3586    LINESTRING (-86.77093 36.19825, -86.77103 36.1...
# 3587    LINESTRING (-86.76408 36.21494, -86.76416 36.2...
# Name: geometry, Length: 3496, dtype: geometry
