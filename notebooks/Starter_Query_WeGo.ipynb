# %%
import requests
import json
import pandas as pd

# %%
with open('../data/WeGo.json') as fi:
    credentials = json.load(fi)

# %%
Authorization = credentials['Authorization']

# %%
URL = 'https://api.goswift.ly/speed-map/nashville/route/55'

params = {
    'direction': '1',
    'startDate': '03-15-2022',
    'resolution': 'hiRes',
}

headers = {'Authorization': Authorization,
          'Content-Type': 'application/json'}

# %%
response = requests.get(URL, params = params, headers = headers)

# %%
res = response.json()
res
# Out:
# {'success': True,
#  'route': '/speed-map/nashville GET',
#  'data': {'segments': [{'pathLocs': [{'lat': 36.09676395233657,
#       'lon': -86.65648904137139},
#      {'lat': 36.09690230447848, 'lon': -86.65670132213874}],
#     'maxSecs': 2.233,
#     'percent90Secs': 1.684,
#     'percent80Secs': 1.571,
#     'percent70Secs': 1.478,
#     'medianSecs': 1.349,
#     'percent30Secs': 1.267,
#     'percent20Secs': 1.225,
#     'percent10Secs': 1.18,
#     'minSecs': 0.956,
#     'pathLengthMeters': 24.504,
#     'averageTravelSeconds': 1.392989,
#     'averageTravelSpeed': 17.59095010800516,
#     'toStop': {'configRev': 49,
#      'stopPathId': 'MURFRANN_to_MURHARWN',
#      'stopId': 'MURHARWN',
#      'stopName': 'Murfreesboro Pike & Harding Pl Wb',
#      'gtfsStopSeq': 15,
#      'pathLength': 686.1,
#      'locations': [{'lat': 36.09439, 'lon': -86.65328},
#       {'lat': 36.09501, 'lon': -86.65392},
#       {'lat': 36.0958, 'lon': -86.65501},
# ...

# %%
res.keys()
# Out:
# dict_keys(['success', 'route', 'data'])

# %%
res['data'].keys()
# Out:
# dict_keys(['segments'])

# %%
res_df = pd.DataFrame(res['data']['segments'])

# %%
res_df
# Out:
#                                               pathLocs  maxSecs  \
# 0    [{'lat': 36.09676395233657, 'lon': -86.6564890...    2.233
# 1    [{'lat': 36.14051454740488, 'lon': -86.7370029...    2.143
# 2    [{'lat': 36.15450750291221, 'lon': -86.7703372...    3.325
# 3    [{'lat': 36.144382064169044, 'lon': -86.748953...    4.934
# 4    [{'lat': 36.13765893714827, 'lon': -86.7284712...    1.941
# ..                                                 ...      ...
# 931  [{'lat': 36.14986999744471, 'lon': -86.7653628...   11.932
# 932  [{'lat': 36.1440428470573, 'lon': -86.74793378...    2.269
# 933  [{'lat': 36.082327371361146, 'lon': -86.646590...    4.226
# 934  [{'lat': 36.157498981033115, 'lon': -86.774067...   24.041
# 935  [{'lat': 36.102851394846844, 'lon': -86.665844...   31.586
#
#      percent90Secs  percent80Secs  percent70Secs  medianSecs  percent30Secs  \
# 0            1.684          1.571          1.478       1.349          1.267
# ...

# %%
res_df.columns
# Out:
# Index(['pathLocs', 'maxSecs', 'percent90Secs', 'percent80Secs',
#        'percent70Secs', 'medianSecs', 'percent30Secs', 'percent20Secs',
#        'percent10Secs', 'minSecs', 'pathLengthMeters', 'averageTravelSeconds',
#        'averageTravelSpeed', 'toStop', 'fromStop', 'countForSegment'],
#       dtype='object')

# %%
res['data']['segments'][0].keys()
# Out:
# dict_keys(['pathLocs', 'maxSecs', 'percent90Secs', 'percent80Secs', 'percent70Secs', 'medianSecs', 'percent30Secs', 'percent20Secs', 'percent10Secs', 'minSecs', 'pathLengthMeters', 'averageTravelSeconds', 'averageTravelSpeed', 'toStop', 'fromStop', 'countForSegment'])

# %%
to_stop1 = pd.DataFrame(res['data']['segments'][0]['toStop'])
to_stop1
# Out:
#    configRev            stopPathId    stopId  \
# 0         49  MURFRANN_to_MURHARWN  MURHARWN
# 1         49  MURFRANN_to_MURHARWN  MURHARWN
# 2         49  MURFRANN_to_MURHARWN  MURHARWN
# 3         49  MURFRANN_to_MURHARWN  MURHARWN
#
#                             stopName  gtfsStopSeq  pathLength  \
# 0  Murfreesboro Pike & Harding Pl Wb           15       686.1
# 1  Murfreesboro Pike & Harding Pl Wb           15       686.1
# 2  Murfreesboro Pike & Harding Pl Wb           15       686.1
# 3  Murfreesboro Pike & Harding Pl Wb           15       686.1
#
#                              locations
# 0  {'lat': 36.09439, 'lon': -86.65328}
# 1  {'lat': 36.09501, 'lon': -86.65392}
# 2   {'lat': 36.0958, 'lon': -86.65501}
# 3  {'lat': 36.09842, 'lon': -86.65903}

# %%
URL2 = 'https://api.goswift.ly/info/nashville/routes'

params2 = {
    'route': '55',
    'verbose': 'True',
}

headers = {'Authorization': Authorization,
          'Content-Type': 'application/json'}

# %%
response2 = requests.get(URL2, params = params2, headers = headers)

# %%
res2 = response2.json()
res2
# Out:
# {'success': True,
#  'route': '/info/nashville/routes GET',
#  'data': {'agencyKey': 'nashville',
#   'routes': [{'id': '55',
#     'name': '55 - Murfreesboro Pike',
#     'shortName': '55',
#     'longName': 'Murfreesboro Pike',
#     'color': 'F32735',
#     'textColor': 'FFFFFF',
#     'type': '3',
#     'directions': [{'id': '0',
#       'title': 'To Hickory Hollow',
#       'stops': [{'id': 'MCC5_11',
#         'lat': 36.16659,
#         'lon': -86.782,
#         'name': 'Central 5th Ave - Bay 11',
#         'minor': True},
#        {'id': 'ARTS',
#         'lat': 36.1314,
#         'lon': -86.7404,
#         'name': 'Arts Magnet School',
#         'minor': True},
#        {'id': 'MCC4_15',
#         'lat': 36.16632,
#         'lon': -86.78145,
#         'name': 'Central 4th Ave - Bay 15'},
#        {'id': '4AVCHUSN',
#         'lat': 36.1638,
#         'lon': -86.77908,
#         'name': '4th Ave N & Church St Sb'},
#        {'id': 'MXOMCCTR',
#         'lat': 36.15926,
# ...
