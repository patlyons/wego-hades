# %%
from shapely.geometry import Point
import pandas as pd
import geopandas as gpd
import requests
import json
import numpy as np
import matplotlib.pyplot as plt
import folium
import re
from folium.plugins import MarkerCluster
from folium.plugins import FastMarkerCluster
import pickle

# %%
with open('../data/route23_all_emo_inschool.pickle', 'rb') as file:
    all_emo_inschool = pickle.load(file)

# %%
with open('../data/route23_slow_am_school_inbound.pickle', 'rb') as file:
    slow_am_school = pickle.load(file)

# %%
with open('../data/route23_slow_am_summer_inbound.pickle', 'rb') as file:
    slow_am_summer = pickle.load(file)

# %%
with open('../data/route23_stop_details.pickle', 'rb') as file:
    stop_details = pickle.load(file)

# %%
with open('../data/route23_slow_lni_school.pickle', 'rb') as file:
    slow_lni_school = pickle.load(file)

# %%
with open('../data/route23_slow_lni_summer.pickle', 'rb') as file:
    slow_lni_summer = pickle.load(file)

# %%
with open('../data/route23_slow_emi_summer.pickle', 'rb') as file:
    slow_emi_summer = pickle.load(file)

# %%
with open('../data/route23_slow_emi_school.pickle', 'rb') as file:
    slow_emi_school = pickle.load(file)

# %%
with open('../data/route23_slow_emo_school.pickle', 'rb') as file:
    slow_emo_school = pickle.load(file)

# %%
with open('../data/route23_slow_emo_summer.pickle', 'rb') as file:
    slow_emo_summer = pickle.load(file)

# %%
full_route = all_emo_inschool['geometry'].to_json()

# %%
stop_geojson = stop_details['geometry'].to_json()

# %%
slow_am_scho_geojson = slow_am_school['geometry'].to_json()

# %%
slow_am_sum_geojson = slow_am_summer['geometry'].to_json()

# %%
slow_emo_scho_geojson = slow_emo_school['geometry'].to_json()

# %%
slow_emo_sum_geojson = slow_emo_summer['geometry'].to_json()

# %%
slow_emi_scho_geojson = slow_emi_school['geometry'].to_json()

# %%
slow_emi_sum_geojson = slow_emi_summer['geometry'].to_json()

# %%
slow_lni_scho_geojson = slow_lni_school['geometry'].to_json()

# %%
slow_lni_sum_geojson = slow_lni_summer['geometry'].to_json()

# %%
from folium.plugins import MarkerCluster

# %%
combined_map = folium.Map(location =  [36.2, -86.7775], zoom_start = 12)

#full_route = folium.FeatureGroup(name='Route 23', show=False)

stops = folium.FeatureGroup(name='Bus Stops', overlay=True, show=False)

#am_in = folium.FeatureGroup(name='Morning Inbound Rush', show=False)
#stops.add_to(combined_map)
combined_map.add_child(stops)
folium.LayerControl(position='topleft', collapsed=False).add_to(combined_map)
#combined_map.add_child(folium.map.LayerControl(collapsed=False))

style1 = {'color': 'gray', 'weight' : 1}
folium.GeoJson(full_route, style_function=lambda x: style1).add_to(combined_map)

style2 = {'color': 'red', 'weight' : 6}
folium.GeoJson(slow_am_scho_geojson, style_function=lambda x: style2).add_to(combined_map)

style3 = {'color': 'blue', 'weight' : 3}
folium.GeoJson(slow_am_sum_geojson, style_function=lambda x: style3).add_to(combined_map)

for row_index, row_values in stop_details.iterrows():
    loc = [row_values['geometry'].y, row_values['geometry'].x]
    pop = str(row_values['stopName'])
    icon= folium.Icon(color="gray",icon="bus", prefix='fa')
    
    marker = folium.Marker(
        location = loc, 
        popup = pop, 
        icon = icon) 

    marker.add_to(stops)

    
combined_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1f155f0b9137a154fa0474963727267f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1f155f0b9137a154fa0474963727267f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_1f155f0b9137a154fa0474963727267f = L.map(
#                 &quot;map_1f155f0b9137a154fa0474963727267f&quot;,
#                 {
#                     center: [36.2, -86.7775],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6930d10d9445e4687e7911495d60dcfc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1f155f0b9137a154fa0474963727267f);
#
#
#             var feature_group_d7a6d52c78b05945324cc91bf60f9d6a = L.featureGroup(
#                 {}
#             ).addTo(map_1f155f0b9137a154fa0474963727267f);
#
#
#             var marker_d34cf461507e817a69107aa15cfc4fff = L.marker(
#                 [36.24425, -86.76052],
#                 {}
#             ).addTo(feature_group_d7a6d52c78b05945324cc91bf60f9d6a);
#
#
#             var icon_b17d0547800c5f2c798d9fe9bcb6db95 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bus&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_d34cf461507e817a69107aa15cfc4fff.setIcon(icon_b17d0547800c5f2c798d9fe9bcb6db95);
#
#
#         var popup_d71c18838b80424c7fa07e8c9e26b934 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_7d7c61be5b6168eb639faac7821eb915 = $(`&lt;div id=&quot;html_7d7c61be5b6168eb639faac7821eb915&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dickerson Rd Wal Mart&lt;/div&gt;`)[0];
#             popup_d71c18838b80424c7fa07e8c9e26b934.setContent(html_7d7c61be5b6168eb639faac7821eb915);
#
#
#         marker_d34cf461507e817a69107aa15cfc4fff.bindPopup(popup_d71c18838b80424c7fa07e8c9e26b934)
#         ;
#
#
#
#
#             var marker_65a0350818e234c02010764bd8bbcaba = L.marker(
#                 [36.24657, -86.75708],
#                 {}
#             ).addTo(feature_group_d7a6d52c78b05945324cc91bf60f9d6a);
#
#
#             var icon_e6e6ad7ebe5d3865f84ff8f697579287 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bus&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_65a0350818e234c02010764bd8bbcaba.setIcon(icon_e6e6ad7ebe5d3865f84ff8f697579287);
#
#
#         var popup_bb38b3a65b6d4514ef9e04768c0d9b09 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_a49ddd27d50304b79fba868ae91939bd = $(`&lt;div id=&quot;html_a49ddd27d50304b79fba868ae91939bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dickerson Rd Walmart Exit&lt;/div&gt;`)[0];
#             popup_bb38b3a65b6d4514ef9e04768c0d9b09.setContent(html_a49ddd27d50304b79fba868ae91939bd);
#
#
#         marker_65a0350818e234c02010764bd8bbcaba.bindPopup(popup_bb38b3a65b6d4514ef9e04768c0d9b09)
#         ;
#
#
#
#
#             var marker_9397d395a82bd725bfa702513588d30b = L.marker(
#                 [36.24418, -86.75659],
#                 {}
#             ).addTo(feature_group_d7a6d52c78b05945324cc91bf60f9d6a);
#
#
#             var icon_e739b91e5114ba33d4cb0cac4ba16947 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bus&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_9397d395a82bd725bfa702513588d30b.setIcon(icon_e739b91e5114ba33d4cb0cac4ba16947);
#
#
#         var popup_c359d84cb83dd6075be45b0dcec02f47 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_2674906e0040ba8d3c0d6dd34ad39f85 = $(`&lt;div id=&quot;html_2674906e0040ba8d3c0d6dd34ad39f85&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dickerson Pike &amp; Doverside Dr Sb&lt;/div&gt;`)[0];
#             popup_c359d84cb83dd6075be45b0dcec02f47.setContent(html_2674906e0040ba8d3c0d6dd34ad39f85);
#
#
#         marker_9397d395a82bd725bfa702513588d30b.bindPopup(popup_c359d84cb83dd6075be45b0dcec02f47)
#         ;
#
#
#
#
#             var marker_76494ed856716f7717c79d602a1c8e9b = L.marker(
#                 [36.23278, -86.75876],
#                 {}
#             ).addTo(feature_group_d7a6d52c78b05945324cc91bf60f9d6a);
#
#
#             var icon_be650c44582e1ed6aaec5ee9d52d7f34 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bus&quot;, &quot;iconColor&quot;: &
